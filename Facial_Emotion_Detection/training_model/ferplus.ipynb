# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np  # linear algebra
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os

for dirname, _, filenames in os.walk("/kaggle/input"):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/fer2013/fer2013.csv
# /kaggle/input/ferplus-csv/ferplus_data.csv
# /kaggle/input/training/best_model_ferplus_Adam_Flatten.keras
# /kaggle/input/emodata-v2/emodata_v2.csv

# %%
import shutil

# Sao chép file từ thư mục nguồn (input) đến thư mục đích (working)
shutil.copy('/kaggle/input/training/best_model_ferplus_Adam_Flatten.keras', '/kaggle/working/')
# Out:
# '/kaggle/working/best_model_ferplus_Adam_Flatten.keras'

# %% [markdown]
# # 1. **Chuẩn bị**

# %% [markdown]
# # 1. 1. Cài đặt các thư viện cần thiết

# %%
# !pip install --upgrade pip
# !pip install numpy==1.26.4 tensorflow==2.17.0  keras==3.2.0  seaborn==0.11.2 scikit-learn==1.2.2 matplotlib==3.7.1 plotly==5.10.0 pandas==2.1.4
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.0.1-py3-none-any.whl.metadata (3.7 kB)
# Downloading pip-25.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 48.2 MB/s eta 0:00:0000:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-25.0.1
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: tensorflow==2.17.0 in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Collecting keras==3.2.0
#   Downloading keras-3.2.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting seaborn==0.11.2
#   Downloading seaborn-0.11.2-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: scikit-learn==1.2.2 in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: matplotlib==3.7.1 in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Collecting plotly==5.10.0
#   Downloading plotly-5.10.0-py2.py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pandas==2.1.4 in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (2.17.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (0.37.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras==3.2.0) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras==3.2.0) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras==3.2.0) (0.12.1)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from seaborn==0.11.2) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.2.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.2.2) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly==5.10.0) (9.0.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.4) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.4) (2024.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.17.0) (0.44.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.0) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.0) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.0) (3.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras==3.2.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras==3.2.0) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras==3.2.0) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow==2.17.0) (2.1.5)
# Downloading keras-3.2.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 31.1 MB/s eta 0:00:00
# Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
# Downloading plotly-5.10.0-py2.py3-none-any.whl (15.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 63.8 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: plotly, seaborn, keras
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.2
#     Uninstalling seaborn-0.12.2:
#       Successfully uninstalled seaborn-0.12.2
#   Attempting uninstall: keras
#     Found existing installation: keras 3.4.1
#     Uninstalling keras-3.4.1:
#       Successfully uninstalled keras-3.4.1
# Successfully installed keras-3.2.0 plotly-5.10.0 seaborn-0.11.2

# %% [markdown]
# # 1. 2. Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import random
import seaborn as sns
import keras
import os
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
import warnings
from tensorflow.keras.models import Sequential, Model
from keras import regularizers
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam, RMSprop, SGD, Adamax
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.utils import plot_model
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Dropout, BatchNormalization, MaxPooling2D, Activation, Input
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import plotly.express as px
import matplotlib.pyplot as plt
import warnings

# Turn off warnings
warnings.simplefilter("ignore")

# %% [markdown]
# # 1. 3. Loading the data

# %%
data = pd.read_csv("/kaggle/input/ferplus-csv/ferplus_data.csv")
print ("Shape of data = ", data.shape)
# Out:
# Shape of data =  (78293, 3)

# %% [markdown]
# # 1. 4. Tổng dữ liệu trống

# %%
data.isnull().sum()
# Out:
# emotion    0
# pixels     0
# Usage      0
# dtype: int64

# %% [markdown]
# # 1. 5. Dữ liệu

# %%
data.head()
# Out:
#    emotion                                             pixels  Usage
# 0        0  0 0 0 19 32 29 40 51 54 53 50 41 34 40 39 33 3...  train
# 1        0  32 49 40 49 44 26 23 19 19 32 54 78 97 116 137...  train
# 2        0  13 29 34 39 42 49 52 48 49 64 65 54 46 47 47 4...  train
# 3        0  0 160 239 233 234 235 235 236 235 246 165 79 5...  train
# 4        0  1 2 2 4 4 4 4 4 4 4 11 13 14 14 20 24 15 21 30...  train

# %% [markdown]
# # **2. Data pre-processing**

# %% [markdown]
# # 2. 1. Bảng phân phối dữ liệu (Training)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
CLASS_LABELS = ['fear', 'surprise', 'angry', 'neutral', 'sad', 'disgust', 'contempt', 'happy']
# Function to plot data distribution from ferplus.csv
def plot_data_distribution_from_csv(data, usage='train'):
 

    # Lọc dữ liệu theo Usage
    filtered_data = data[data['Usage'] == usage]

    # Đếm số lượng mẫu cho từng nhãn cảm xúc
    emotion_counts = filtered_data['emotion'].value_counts().sort_index()

    # Gán nhãn cảm xúc
   

    # Tạo biểu đồ
    plt.figure(figsize=(10, 6))
    sns.barplot(x=CLASS_LABELS, y=emotion_counts, palette="viridis")

    # Hiển thị số lượng trên các cột
    for i, count in enumerate(emotion_counts):
        plt.text(
            i,
            count + 0.5,
            str(count),
            ha="center",
            va="bottom",
            fontsize=12,
            color="black",
        )

    # Cập nhật tiêu đề và nhãn
    plt.title(f"Data Distribution in {usage} Set")
    plt.xlabel("Class")
    plt.ylabel("Number of Samples")
    plt.xticks(rotation=45)
    plt.show()

# Gọi hàm với đường dẫn tới ferplus.csv
plot_data_distribution_from_csv(data, usage='train')

# %% [markdown]
# # 3. 2. Shuffling the data

# %%
# Shuffle và reset index
data = data.sample(frac=1, random_state=42).reset_index(drop=True)

# %% [markdown]
# # 3. 3. One Hot Encoding

# %%
# Chuẩn bị nhãn
labels = to_categorical(data['emotion'], num_classes=8)  # Chuyển đổi nhãn cảm xúc thành one-hot encoding

# %% [markdown]
# # 3. 4. Chuyển đổi pixel từ chuỗi sang mảng 48x48 và thay đổi kiểu dữ liệu thành float32

# %%
pixels = np.array([np.fromstring(p, sep=' ') for p in data['pixels']], dtype='float32')
pixels = pixels.reshape((data.shape[0], 48, 48, 1))  # Đảm bảo dữ liệu có hình dạng (n, 48, 48, 1)

# %% [markdown]
# # **4. Train test validation split**

# %% [markdown]
# # 4. 1. Chuẩn hóa dữ liệu pixel

# %%
scaler = StandardScaler()
pixels = scaler.fit_transform(pixels.reshape((data.shape[0], -1))).reshape((data.shape[0], 48, 48, 1))

# %% [markdown]
# # 4. 2. Chia dữ liệu (Train - 80% - Test - 10% - Val - 20%)

# %%
from sklearn.model_selection import train_test_split

# Chia tập dữ liệu thành tập huấn luyện và tập kiểm tra (90% - 10%)
X_train, X_test, y_train, y_test = train_test_split(pixels, labels, test_size=0.1, shuffle=False)

# Chia tập huấn luyện thành tập huấn luyện và tập validation (90% huấn luyện, 20% validation)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, shuffle=False)

# %%
print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)
print("Validation shape:", X_val.shape)
# Out:
# Train shape: (56370, 48, 48, 1)
# Test shape: (7830, 48, 48, 1)
# Validation shape: (14093, 48, 48, 1)

# %% [markdown]
# # **5. Data augmentation using ImageDataGenerator**

# %%
# datagen = ImageDataGenerator(  width_shift_range = 0.1,
#                                height_shift_range = 0.1,
#                                horizontal_flip = True,
#                                zoom_range = 0.2)
# valgen = ImageDataGenerator(   width_shift_range = 0.1,
#                                height_shift_range = 0.1,
#                                horizontal_flip = True,
#                                zoom_range = 0.2)

# %% [markdown]
# # 5. 1. Tăng cường dữ liệu

# %%
datagen = ImageDataGenerator(
    # Các tham số chuẩn hóa và bình thường hóa dữ liệu
    featurewise_center=False,  
    samplewise_center=False,  
    featurewise_std_normalization=False,  
    samplewise_std_normalization=False,  
    
    # Các phép biến đổi hình ảnh
    rotation_range=20,  # Xoay hình ảnh trong phạm vi từ 0 đến 20 độ
    zoom_range=0.2,  # Tăng giảm kích thước ảnh (zoom in/out)
    width_shift_range=0.1,  # Dịch chuyển hình ảnh theo chiều ngang (10% ảnh)
    height_shift_range=0.1,  # Dịch chuyển hình ảnh theo chiều dọc (10% ảnh)
    
    # Lật hình ảnh ngang hoặc dọc
    horizontal_flip=True,  # Lật ảnh theo chiều ngang (phù hợp với nhiều dữ liệu)
    vertical_flip=False,  # Tắt lật ảnh theo chiều dọc (thường không cần với bộ dữ liệu cảm xúc)
    
    # Các phương pháp khác để cải thiện mô hình
    shear_range=0.2,  # Xoay nghiêng ảnh theo một góc nhất định
    fill_mode='nearest',  # Cách điền các pixel bị thiếu sau khi thực hiện các phép biến đổi (nearest là phương pháp tốt nhất cho ảnh)
)

valgen = ImageDataGenerator()

# %%
datagen.fit(X_train)
# valgen.fit(X_val)

# %%
train_generator = datagen.flow(X_train, y_train, batch_size=32)
val_generator = datagen.flow(X_val, y_val, batch_size=32)

# %% [markdown]
# # 5. 2. Hiển thị mỗi một ảnh ngẫu nhiên tương ứng với 7 class

# %%
import numpy as np
import matplotlib.pyplot as plt

# 
plt.figure(figsize=(15, 23))

label_dict = {0: "fear", 1: "surprise", 2: "angry", 3: "neutral", 4: "sad", 5: "disgust", 6: "contempt", 7: "happy"}

# Lặp qua từng class
for i in range(8):
    # Lọc các chỉ số của ảnh thuộc class hiện tại
    class_indices = np.where(np.argmax(y_train, axis=1) == i)[0]
    # Chọn ngẫu nhiên một chỉ số từ class hiện tại
    random_index = np.random.choice(class_indices)
    # Lấy ảnh ngẫu nhiên từ class hiện tại
    img = np.squeeze(X_train[random_index])
    
    # Hiển thị ảnh
    plt.subplot(1, 8, i + 1)
    plt.imshow(img, cmap='gray')
    plt.title(CLASS_LABELS[i])
    plt.axis('off')

plt.show()

# %% [markdown]
# # **6. Design a model**

# %% [markdown]
# # 6. 1. CNN model with Adam - Flatten

# %%
import tensorflow as tf
from tensorflow.keras.layers import (
    Conv2D, BatchNormalization, MaxPool2D, Dropout, Flatten, Dense
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers

def cnn_model_Flatten():
    model = tf.keras.models.Sequential()
    
    # Layer 1
    model.add(Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', input_shape=(48, 48, 1)))
    
    # Layer 2
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPool2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))  # Dropout thấp để giữ thông tin
    
    # Layer 3
    model.add(Conv2D(128, (5, 5), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPool2D(pool_size=(2, 2)))
    model.add(Dropout(0.3))  # Dropout trung bình để tránh overfitting
    
    # Layer 4
    model.add(Conv2D(512, (3, 3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(MaxPool2D(pool_size=(2, 2)))
    model.add(Dropout(0.3))  # Tăng nhẹ Dropout ở layer sâu hơn
    
    # Layer 5
    model.add(Conv2D(512, (3, 3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(MaxPool2D(pool_size=(2, 2)))
    model.add(Dropout(0.35))  # Tăng Dropout để giảm overfitting ở layer phức tạp
    
    # Layer 6
    model.add(Conv2D(512, (3, 3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(MaxPool2D(pool_size=(2, 2)))
    model.add(Dropout(0.4))  # Dropout cao nhất ở layer sâu nhất
    
    # Flatten và Fully Connected Layers
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))  # Fully Connected cần Dropout cao
    
    model.add(Dense(512, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))  # Fully Connected cần Dropout cao
    
    # Output Layer
    model.add(Dense(8, activation='softmax'))
    
    # Compile Model
    model.compile(
        optimizer=Adam(learning_rate=0.0001),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
model = cnn_model_Flatten()

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 48, 48, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 48, 48, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 48, 48, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 24, 24, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 24, 24, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 24, 24, 128)         │         204,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 24, 24, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 12, 12, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 12, 12, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 12, 12, 512)         │         590,336 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 12, 12, 512)         │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 6, 6, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 6, 6, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 6, 6, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 6, 6, 512)           │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 3, 3, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 3, 3, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 3, 3, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 3, 3, 512)           │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 1, 1, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 1, 1, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 8)                   │           4,104 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,810,696 (22.17 MB)
#  Trainable params: 5,805,704 (22.15 MB)
#  Non-trainable params: 4,992 (19.50 KB)

# %% [markdown]
# # 6. 2. Early stopping

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
# Các callback
checkpointer = [
    EarlyStopping(
        monitor='val_loss',  # Theo dõi loss của tập validation
        verbose=1,
        restore_best_weights=True,
        mode="min",  # Theo dõi loss thấp nhất
        patience=20  # Tăng patience để mô hình có thêm thời gian học
    ),
    ModelCheckpoint(
        'best_model_ferplus_Adam_Flatten.keras',
        monitor="val_loss",  # Lưu mô hình tốt nhất dựa trên loss của tập validation
        verbose=1,
        save_best_only=True,
        mode="min"  # Dựa vào loss thấp nhất
    ),
    ReduceLROnPlateau(
        monitor='val_loss',  # Giảm learning rate nếu loss trên tập validation không cải thiện
        factor=0.5,  # Giảm learning rate chậm hơn
        patience=5,  # Giảm learning rate sau 5 epochs nếu không cải thiện
        min_lr=0.000001,
        verbose=1
    )
]

# %%
from tensorflow.keras.models import load_model

# Tải lại mô hình đã lưu
model = load_model('/kaggle/input/trainned/best_model_ferplus_Adam_Flatten.keras')

# %%
history = model.fit(train_generator,
                    epochs=500,
                    batch_size=32,
                    verbose=1,
                    callbacks=[checkpointer],
                    validation_data=val_generator)
# Out:
# Epoch 1/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8769 - loss: 0.5141
# Epoch 1: val_loss improved from 7.24442 to 0.45592, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 49s 23ms/step - accuracy: 0.8769 - loss: 0.5141 - val_accuracy: 0.8952 - val_loss: 0.4559 - learning_rate: 6.2500e-06
# Epoch 2/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8748 - loss: 0.5126
# Epoch 2: val_loss improved from 0.45592 to 0.45516, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8748 - loss: 0.5126 - val_accuracy: 0.8940 - val_loss: 0.4552 - learning_rate: 6.2500e-06
# Epoch 3/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8765 - loss: 0.5117
# Epoch 3: val_loss did not improve from 0.45516
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8765 - loss: 0.5117 - val_accuracy: 0.8932 - val_loss: 0.4583 - learning_rate: 6.2500e-06
# Epoch 4/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8749 - loss: 0.5174
# Epoch 4: val_loss improved from 0.45516 to 0.45387, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8749 - loss: 0.5174 - val_accuracy: 0.8956 - val_loss: 0.4539 - learning_rate: 6.2500e-06
# Epoch 5/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8755 - loss: 0.5121
# Epoch 5: val_loss improved from 0.45387 to 0.44778, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8755 - loss: 0.5121 - val_accuracy: 0.8954 - val_loss: 0.4478 - learning_rate: 6.2500e-06
# Epoch 6/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8772 - loss: 0.5082
# Epoch 6: val_loss did not improve from 0.44778
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8772 - loss: 0.5082 - val_accuracy: 0.8963 - val_loss: 0.4497 - learning_rate: 6.2500e-06
# Epoch 7/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8753 - loss: 0.5160
# Epoch 7: val_loss improved from 0.44778 to 0.44762, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8753 - loss: 0.5160 - val_accuracy: 0.8975 - val_loss: 0.4476 - learning_rate: 6.2500e-06
# Epoch 8/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8807 - loss: 0.5001
# Epoch 8: val_loss improved from 0.44762 to 0.44597, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8807 - loss: 0.5001 - val_accuracy: 0.8966 - val_loss: 0.4460 - learning_rate: 6.2500e-06
# Epoch 9/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8760 - loss: 0.5062
# Epoch 9: val_loss did not improve from 0.44597
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8760 - loss: 0.5062 - val_accuracy: 0.8962 - val_loss: 0.4526 - learning_rate: 6.2500e-06
# Epoch 10/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8786 - loss: 0.5035
# Epoch 10: val_loss improved from 0.44597 to 0.44584, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 18ms/step - accuracy: 0.8786 - loss: 0.5035 - val_accuracy: 0.8982 - val_loss: 0.4458 - learning_rate: 6.2500e-06
# Epoch 11/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8773 - loss: 0.5113
# Epoch 11: val_loss improved from 0.44584 to 0.44128, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 18ms/step - accuracy: 0.8773 - loss: 0.5113 - val_accuracy: 0.8973 - val_loss: 0.4413 - learning_rate: 6.2500e-06
# Epoch 12/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8809 - loss: 0.4963
# Epoch 12: val_loss did not improve from 0.44128
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8809 - loss: 0.4963 - val_accuracy: 0.8941 - val_loss: 0.4469 - learning_rate: 6.2500e-06
# Epoch 13/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8804 - loss: 0.4985
# Epoch 13: val_loss did not improve from 0.44128
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8804 - loss: 0.4986 - val_accuracy: 0.8942 - val_loss: 0.4529 - learning_rate: 6.2500e-06
# Epoch 14/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8742 - loss: 0.5089
# Epoch 14: val_loss did not improve from 0.44128
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8742 - loss: 0.5089 - val_accuracy: 0.8965 - val_loss: 0.4456 - learning_rate: 6.2500e-06
# Epoch 15/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8769 - loss: 0.5018
# Epoch 15: val_loss did not improve from 0.44128
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8769 - loss: 0.5018 - val_accuracy: 0.8970 - val_loss: 0.4489 - learning_rate: 6.2500e-06
# Epoch 16/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8800 - loss: 0.4948
# Epoch 16: val_loss improved from 0.44128 to 0.44123, saving model to best_model_ferplus_Adam_Flatten.keras
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8800 - loss: 0.4948 - val_accuracy: 0.8993 - val_loss: 0.4412 - learning_rate: 6.2500e-06
# Epoch 17/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8804 - loss: 0.4899
# Epoch 17: val_loss did not improve from 0.44123
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8804 - loss: 0.4899 - val_accuracy: 0.8980 - val_loss: 0.4426 - learning_rate: 3.1250e-06
# Epoch 18/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8819 - loss: 0.4912
# Epoch 18: val_loss improved from 0.44123 to 0.43734, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 18ms/step - accuracy: 0.8819 - loss: 0.4912 - val_accuracy: 0.8988 - val_loss: 0.4373 - learning_rate: 3.1250e-06
# Epoch 19/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8811 - loss: 0.4864
# Epoch 19: val_loss improved from 0.43734 to 0.43597, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 18ms/step - accuracy: 0.8811 - loss: 0.4864 - val_accuracy: 0.8983 - val_loss: 0.4360 - learning_rate: 3.1250e-06
# Epoch 20/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8824 - loss: 0.4894
# Epoch 20: val_loss improved from 0.43597 to 0.43560, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8824 - loss: 0.4894 - val_accuracy: 0.8998 - val_loss: 0.4356 - learning_rate: 3.1250e-06
# Epoch 21/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8823 - loss: 0.4881
# Epoch 21: val_loss improved from 0.43560 to 0.43257, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8823 - loss: 0.4880 - val_accuracy: 0.8991 - val_loss: 0.4326 - learning_rate: 3.1250e-06
# Epoch 22/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8856 - loss: 0.4763
# Epoch 22: val_loss did not improve from 0.43257
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8856 - loss: 0.4763 - val_accuracy: 0.8978 - val_loss: 0.4373 - learning_rate: 3.1250e-06
# Epoch 23/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8846 - loss: 0.4789
# Epoch 23: val_loss did not improve from 0.43257
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8846 - loss: 0.4789 - val_accuracy: 0.8982 - val_loss: 0.4333 - learning_rate: 3.1250e-06
# Epoch 24/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8843 - loss: 0.4789
# Epoch 24: val_loss improved from 0.43257 to 0.43151, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 18ms/step - accuracy: 0.8843 - loss: 0.4789 - val_accuracy: 0.8956 - val_loss: 0.4315 - learning_rate: 3.1250e-06
# Epoch 25/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8828 - loss: 0.4811
# Epoch 25: val_loss did not improve from 0.43151
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 18ms/step - accuracy: 0.8828 - loss: 0.4811 - val_accuracy: 0.8991 - val_loss: 0.4328 - learning_rate: 3.1250e-06
# Epoch 26/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8840 - loss: 0.4736
# Epoch 26: val_loss improved from 0.43151 to 0.42510, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8840 - loss: 0.4736 - val_accuracy: 0.9014 - val_loss: 0.4251 - learning_rate: 3.1250e-06
# Epoch 27/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8856 - loss: 0.4747
# Epoch 27: val_loss did not improve from 0.42510
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8855 - loss: 0.4747 - val_accuracy: 0.8995 - val_loss: 0.4290 - learning_rate: 3.1250e-06
# Epoch 28/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8840 - loss: 0.4688
# Epoch 28: val_loss improved from 0.42510 to 0.42356, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8840 - loss: 0.4688 - val_accuracy: 0.9009 - val_loss: 0.4236 - learning_rate: 3.1250e-06
# Epoch 29/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8868 - loss: 0.4666
# Epoch 29: val_loss improved from 0.42356 to 0.42261, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8868 - loss: 0.4666 - val_accuracy: 0.9017 - val_loss: 0.4226 - learning_rate: 3.1250e-06
# Epoch 30/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8833 - loss: 0.4719
# Epoch 30: val_loss improved from 0.42261 to 0.42070, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8833 - loss: 0.4719 - val_accuracy: 0.9039 - val_loss: 0.4207 - learning_rate: 3.1250e-06
# Epoch 31/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8840 - loss: 0.4691
# Epoch 31: val_loss did not improve from 0.42070
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8840 - loss: 0.4691 - val_accuracy: 0.9002 - val_loss: 0.4239 - learning_rate: 3.1250e-06
# Epoch 32/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8869 - loss: 0.4634
# Epoch 32: val_loss did not improve from 0.42070
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8869 - loss: 0.4634 - val_accuracy: 0.9013 - val_loss: 0.4210 - learning_rate: 3.1250e-06
# Epoch 33/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8858 - loss: 0.4677
# Epoch 33: val_loss did not improve from 0.42070
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8858 - loss: 0.4677 - val_accuracy: 0.8994 - val_loss: 0.4208 - learning_rate: 3.1250e-06
# Epoch 34/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8861 - loss: 0.4647
# Epoch 34: val_loss improved from 0.42070 to 0.41987, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8861 - loss: 0.4647 - val_accuracy: 0.9007 - val_loss: 0.4199 - learning_rate: 3.1250e-06
# Epoch 35/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8849 - loss: 0.4626
# Epoch 35: val_loss did not improve from 0.41987
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8849 - loss: 0.4626 - val_accuracy: 0.8993 - val_loss: 0.4219 - learning_rate: 3.1250e-06
# Epoch 36/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8866 - loss: 0.4623
# Epoch 36: val_loss did not improve from 0.41987
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8866 - loss: 0.4623 - val_accuracy: 0.9014 - val_loss: 0.4211 - learning_rate: 3.1250e-06
# Epoch 37/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8892 - loss: 0.4573
# Epoch 37: val_loss improved from 0.41987 to 0.41866, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8892 - loss: 0.4573 - val_accuracy: 0.9006 - val_loss: 0.4187 - learning_rate: 3.1250e-06
# Epoch 38/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8871 - loss: 0.4563
# Epoch 38: val_loss improved from 0.41866 to 0.41281, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8871 - loss: 0.4563 - val_accuracy: 0.9032 - val_loss: 0.4128 - learning_rate: 3.1250e-06
# Epoch 39/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8876 - loss: 0.4608
# Epoch 39: val_loss did not improve from 0.41281
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8876 - loss: 0.4608 - val_accuracy: 0.9017 - val_loss: 0.4194 - learning_rate: 3.1250e-06
# Epoch 40/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8831 - loss: 0.4641
# Epoch 40: val_loss did not improve from 0.41281
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8831 - loss: 0.4641 - val_accuracy: 0.9030 - val_loss: 0.4159 - learning_rate: 3.1250e-06
# Epoch 41/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8873 - loss: 0.4578
# Epoch 41: val_loss did not improve from 0.41281
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8873 - loss: 0.4578 - val_accuracy: 0.8994 - val_loss: 0.4203 - learning_rate: 3.1250e-06
# Epoch 42/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8854 - loss: 0.4592
# Epoch 42: val_loss did not improve from 0.41281
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8854 - loss: 0.4592 - val_accuracy: 0.9002 - val_loss: 0.4169 - learning_rate: 3.1250e-06
# Epoch 43/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8881 - loss: 0.4537
# Epoch 43: val_loss improved from 0.41281 to 0.41212, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8881 - loss: 0.4537 - val_accuracy: 0.9033 - val_loss: 0.4121 - learning_rate: 3.1250e-06
# Epoch 44/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8859 - loss: 0.4589
# Epoch 44: val_loss did not improve from 0.41212
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 18ms/step - accuracy: 0.8859 - loss: 0.4589 - val_accuracy: 0.9028 - val_loss: 0.4138 - learning_rate: 3.1250e-06
# Epoch 45/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8880 - loss: 0.4523
# Epoch 45: val_loss improved from 0.41212 to 0.41149, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 18ms/step - accuracy: 0.8881 - loss: 0.4523 - val_accuracy: 0.9034 - val_loss: 0.4115 - learning_rate: 3.1250e-06
# Epoch 46/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8890 - loss: 0.4523
# Epoch 46: val_loss did not improve from 0.41149
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8890 - loss: 0.4523 - val_accuracy: 0.9002 - val_loss: 0.4140 - learning_rate: 3.1250e-06
# Epoch 47/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8882 - loss: 0.4502
# Epoch 47: val_loss improved from 0.41149 to 0.40611, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8882 - loss: 0.4502 - val_accuracy: 0.9026 - val_loss: 0.4061 - learning_rate: 3.1250e-06
# Epoch 48/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8904 - loss: 0.4455
# Epoch 48: val_loss did not improve from 0.40611
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8904 - loss: 0.4455 - val_accuracy: 0.9046 - val_loss: 0.4069 - learning_rate: 3.1250e-06
# Epoch 49/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8909 - loss: 0.4488
# Epoch 49: val_loss did not improve from 0.40611
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8909 - loss: 0.4488 - val_accuracy: 0.9007 - val_loss: 0.4174 - learning_rate: 3.1250e-06
# Epoch 50/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8880 - loss: 0.4486
# Epoch 50: val_loss improved from 0.40611 to 0.40427, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8880 - loss: 0.4486 - val_accuracy: 0.9060 - val_loss: 0.4043 - learning_rate: 3.1250e-06
# Epoch 51/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8894 - loss: 0.4472
# Epoch 51: val_loss did not improve from 0.40427
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8894 - loss: 0.4472 - val_accuracy: 0.9023 - val_loss: 0.4117 - learning_rate: 3.1250e-06
# Epoch 52/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8896 - loss: 0.4440
# Epoch 52: val_loss did not improve from 0.40427
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8896 - loss: 0.4440 - val_accuracy: 0.9039 - val_loss: 0.4088 - learning_rate: 3.1250e-06
# Epoch 53/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8879 - loss: 0.4472
# Epoch 53: val_loss did not improve from 0.40427
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8880 - loss: 0.4472 - val_accuracy: 0.9023 - val_loss: 0.4143 - learning_rate: 3.1250e-06
# Epoch 54/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8884 - loss: 0.4443
# Epoch 54: val_loss did not improve from 0.40427
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8884 - loss: 0.4443 - val_accuracy: 0.9013 - val_loss: 0.4129 - learning_rate: 3.1250e-06
# Epoch 55/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8914 - loss: 0.4410
# Epoch 55: val_loss did not improve from 0.40427
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8914 - loss: 0.4411 - val_accuracy: 0.9031 - val_loss: 0.4067 - learning_rate: 3.1250e-06
# Epoch 56/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8897 - loss: 0.4446
# Epoch 56: val_loss did not improve from 0.40427
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8897 - loss: 0.4446 - val_accuracy: 0.9024 - val_loss: 0.4064 - learning_rate: 1.5625e-06
# Epoch 57/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8934 - loss: 0.4353
# Epoch 57: val_loss did not improve from 0.40427
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8934 - loss: 0.4353 - val_accuracy: 0.9032 - val_loss: 0.4061 - learning_rate: 1.5625e-06
# Epoch 58/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8925 - loss: 0.4367
# Epoch 58: val_loss did not improve from 0.40427
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8925 - loss: 0.4367 - val_accuracy: 0.9014 - val_loss: 0.4060 - learning_rate: 1.5625e-06
# Epoch 59/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8951 - loss: 0.4310
# Epoch 59: val_loss improved from 0.40427 to 0.40363, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8950 - loss: 0.4310 - val_accuracy: 0.9037 - val_loss: 0.4036 - learning_rate: 1.5625e-06
# Epoch 60/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8908 - loss: 0.4348
# Epoch 60: val_loss improved from 0.40363 to 0.39978, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8908 - loss: 0.4348 - val_accuracy: 0.9046 - val_loss: 0.3998 - learning_rate: 1.5625e-06
# Epoch 61/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8917 - loss: 0.4364
# Epoch 61: val_loss did not improve from 0.39978
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8917 - loss: 0.4364 - val_accuracy: 0.9015 - val_loss: 0.4019 - learning_rate: 1.5625e-06
# Epoch 62/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8938 - loss: 0.4398
# Epoch 62: val_loss improved from 0.39978 to 0.39819, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8938 - loss: 0.4398 - val_accuracy: 0.9041 - val_loss: 0.3982 - learning_rate: 1.5625e-06
# Epoch 63/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8951 - loss: 0.4222
# Epoch 63: val_loss did not improve from 0.39819
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8951 - loss: 0.4223 - val_accuracy: 0.9017 - val_loss: 0.4029 - learning_rate: 1.5625e-06
# Epoch 64/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8955 - loss: 0.4287
# Epoch 64: val_loss did not improve from 0.39819
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8955 - loss: 0.4287 - val_accuracy: 0.9028 - val_loss: 0.4060 - learning_rate: 1.5625e-06
# Epoch 65/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8914 - loss: 0.4362
# Epoch 65: val_loss improved from 0.39819 to 0.39692, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8914 - loss: 0.4362 - val_accuracy: 0.9043 - val_loss: 0.3969 - learning_rate: 1.5625e-06
# Epoch 66/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8923 - loss: 0.4333
# Epoch 66: val_loss did not improve from 0.39692
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8923 - loss: 0.4333 - val_accuracy: 0.9041 - val_loss: 0.3974 - learning_rate: 1.5625e-06
# Epoch 67/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8914 - loss: 0.4290
# Epoch 67: val_loss improved from 0.39692 to 0.39674, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 18ms/step - accuracy: 0.8914 - loss: 0.4290 - val_accuracy: 0.9045 - val_loss: 0.3967 - learning_rate: 1.5625e-06
# Epoch 68/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8955 - loss: 0.4258
# Epoch 68: val_loss did not improve from 0.39674
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8955 - loss: 0.4258 - val_accuracy: 0.9041 - val_loss: 0.3985 - learning_rate: 1.5625e-06
# Epoch 69/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8933 - loss: 0.4319
# Epoch 69: val_loss did not improve from 0.39674
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8933 - loss: 0.4318 - val_accuracy: 0.9030 - val_loss: 0.4013 - learning_rate: 1.5625e-06
# Epoch 70/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8947 - loss: 0.4260
# Epoch 70: val_loss did not improve from 0.39674
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8947 - loss: 0.4260 - val_accuracy: 0.9030 - val_loss: 0.3997 - learning_rate: 1.5625e-06
# Epoch 71/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8931 - loss: 0.4263
# Epoch 71: val_loss did not improve from 0.39674
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8931 - loss: 0.4263 - val_accuracy: 0.9039 - val_loss: 0.3990 - learning_rate: 1.5625e-06
# Epoch 72/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8965 - loss: 0.4247
# Epoch 72: val_loss did not improve from 0.39674
#
# Epoch 72: ReduceLROnPlateau reducing learning rate to 1e-06.
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8965 - loss: 0.4247 - val_accuracy: 0.9044 - val_loss: 0.3984 - learning_rate: 1.5625e-06
# Epoch 73/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8973 - loss: 0.4181
# Epoch 73: val_loss improved from 0.39674 to 0.39490, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8973 - loss: 0.4182 - val_accuracy: 0.9045 - val_loss: 0.3949 - learning_rate: 1.0000e-06
# Epoch 74/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8951 - loss: 0.4244
# Epoch 74: val_loss improved from 0.39490 to 0.39031, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8951 - loss: 0.4244 - val_accuracy: 0.9046 - val_loss: 0.3903 - learning_rate: 1.0000e-06
# Epoch 75/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8944 - loss: 0.4204
# Epoch 75: val_loss did not improve from 0.39031
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8944 - loss: 0.4204 - val_accuracy: 0.9025 - val_loss: 0.3957 - learning_rate: 1.0000e-06
# Epoch 76/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8962 - loss: 0.4233
# Epoch 76: val_loss did not improve from 0.39031
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8962 - loss: 0.4233 - val_accuracy: 0.9020 - val_loss: 0.3989 - learning_rate: 1.0000e-06
# Epoch 77/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8912 - loss: 0.4275
# Epoch 77: val_loss did not improve from 0.39031
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8912 - loss: 0.4275 - val_accuracy: 0.9043 - val_loss: 0.3964 - learning_rate: 1.0000e-06
# Epoch 78/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8949 - loss: 0.4264
# Epoch 78: val_loss did not improve from 0.39031
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8949 - loss: 0.4264 - val_accuracy: 0.9026 - val_loss: 0.3931 - learning_rate: 1.0000e-06
# Epoch 79/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8968 - loss: 0.4162
# Epoch 79: val_loss did not improve from 0.39031
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8968 - loss: 0.4162 - val_accuracy: 0.9040 - val_loss: 0.3972 - learning_rate: 1.0000e-06
# Epoch 80/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8975 - loss: 0.4188
# Epoch 80: val_loss did not improve from 0.39031
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8975 - loss: 0.4188 - val_accuracy: 0.9027 - val_loss: 0.3984 - learning_rate: 1.0000e-06
# Epoch 81/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8964 - loss: 0.4194
# Epoch 81: val_loss did not improve from 0.39031
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8964 - loss: 0.4194 - val_accuracy: 0.9049 - val_loss: 0.3946 - learning_rate: 1.0000e-06
# Epoch 82/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8940 - loss: 0.4244
# Epoch 82: val_loss did not improve from 0.39031
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8940 - loss: 0.4244 - val_accuracy: 0.9042 - val_loss: 0.3967 - learning_rate: 1.0000e-06
# Epoch 83/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8985 - loss: 0.4137
# Epoch 83: val_loss did not improve from 0.39031
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8985 - loss: 0.4137 - val_accuracy: 0.9026 - val_loss: 0.3968 - learning_rate: 1.0000e-06
# Epoch 84/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8964 - loss: 0.4147
# Epoch 84: val_loss did not improve from 0.39031
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8964 - loss: 0.4147 - val_accuracy: 0.9039 - val_loss: 0.3918 - learning_rate: 1.0000e-06
# Epoch 85/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8966 - loss: 0.4153
# Epoch 85: val_loss did not improve from 0.39031
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8966 - loss: 0.4153 - val_accuracy: 0.9063 - val_loss: 0.3906 - learning_rate: 1.0000e-06
# Epoch 86/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8966 - loss: 0.4155
# Epoch 86: val_loss did not improve from 0.39031
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8966 - loss: 0.4155 - val_accuracy: 0.9050 - val_loss: 0.3962 - learning_rate: 1.0000e-06
# Epoch 87/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8939 - loss: 0.4246
# Epoch 87: val_loss did not improve from 0.39031
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8939 - loss: 0.4246 - val_accuracy: 0.9032 - val_loss: 0.3977 - learning_rate: 1.0000e-06
# Epoch 88/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8966 - loss: 0.4209
# Epoch 88: val_loss did not improve from 0.39031
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8967 - loss: 0.4209 - val_accuracy: 0.9048 - val_loss: 0.3922 - learning_rate: 1.0000e-06
# Epoch 89/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8961 - loss: 0.4103
# Epoch 89: val_loss improved from 0.39031 to 0.38939, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8961 - loss: 0.4103 - val_accuracy: 0.9056 - val_loss: 0.3894 - learning_rate: 1.0000e-06
# Epoch 90/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8949 - loss: 0.4154
# Epoch 90: val_loss did not improve from 0.38939
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8949 - loss: 0.4154 - val_accuracy: 0.9039 - val_loss: 0.3947 - learning_rate: 1.0000e-06
# Epoch 91/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8964 - loss: 0.4124
# Epoch 91: val_loss did not improve from 0.38939
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8964 - loss: 0.4124 - val_accuracy: 0.9056 - val_loss: 0.3915 - learning_rate: 1.0000e-06
# Epoch 92/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8946 - loss: 0.4170
# Epoch 92: val_loss did not improve from 0.38939
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8946 - loss: 0.4170 - val_accuracy: 0.9064 - val_loss: 0.3909 - learning_rate: 1.0000e-06
# Epoch 93/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8978 - loss: 0.4121
# Epoch 93: val_loss did not improve from 0.38939
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8978 - loss: 0.4121 - val_accuracy: 0.9037 - val_loss: 0.3919 - learning_rate: 1.0000e-06
# Epoch 94/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8968 - loss: 0.4125
# Epoch 94: val_loss did not improve from 0.38939
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8968 - loss: 0.4125 - val_accuracy: 0.9056 - val_loss: 0.3952 - learning_rate: 1.0000e-06
# Epoch 95/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8954 - loss: 0.4199
# Epoch 95: val_loss did not improve from 0.38939
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8954 - loss: 0.4199 - val_accuracy: 0.9061 - val_loss: 0.3905 - learning_rate: 1.0000e-06
# Epoch 96/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8958 - loss: 0.4147
# Epoch 96: val_loss improved from 0.38939 to 0.38666, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8958 - loss: 0.4147 - val_accuracy: 0.9079 - val_loss: 0.3867 - learning_rate: 1.0000e-06
# Epoch 97/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8985 - loss: 0.4095
# Epoch 97: val_loss did not improve from 0.38666
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8985 - loss: 0.4095 - val_accuracy: 0.9054 - val_loss: 0.3876 - learning_rate: 1.0000e-06
# Epoch 98/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8997 - loss: 0.4095
# Epoch 98: val_loss did not improve from 0.38666
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8997 - loss: 0.4095 - val_accuracy: 0.9058 - val_loss: 0.3911 - learning_rate: 1.0000e-06
# Epoch 99/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8977 - loss: 0.4122
# Epoch 99: val_loss did not improve from 0.38666
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8977 - loss: 0.4122 - val_accuracy: 0.9051 - val_loss: 0.3924 - learning_rate: 1.0000e-06
# Epoch 100/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8953 - loss: 0.4146
# Epoch 100: val_loss did not improve from 0.38666
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8953 - loss: 0.4146 - val_accuracy: 0.9038 - val_loss: 0.3870 - learning_rate: 1.0000e-06
# Epoch 101/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8945 - loss: 0.4126
# Epoch 101: val_loss did not improve from 0.38666
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8945 - loss: 0.4126 - val_accuracy: 0.9033 - val_loss: 0.3899 - learning_rate: 1.0000e-06
# Epoch 102/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8993 - loss: 0.4094
# Epoch 102: val_loss did not improve from 0.38666
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 18ms/step - accuracy: 0.8993 - loss: 0.4094 - val_accuracy: 0.9075 - val_loss: 0.3894 - learning_rate: 1.0000e-06
# Epoch 103/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8964 - loss: 0.4107
# Epoch 103: val_loss improved from 0.38666 to 0.38470, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8964 - loss: 0.4107 - val_accuracy: 0.9063 - val_loss: 0.3847 - learning_rate: 1.0000e-06
# Epoch 104/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8964 - loss: 0.4119
# Epoch 104: val_loss did not improve from 0.38470
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8964 - loss: 0.4119 - val_accuracy: 0.9082 - val_loss: 0.3884 - learning_rate: 1.0000e-06
# Epoch 105/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8967 - loss: 0.4111
# Epoch 105: val_loss did not improve from 0.38470
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8967 - loss: 0.4111 - val_accuracy: 0.9053 - val_loss: 0.3881 - learning_rate: 1.0000e-06
# Epoch 106/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9017 - loss: 0.4003
# Epoch 106: val_loss did not improve from 0.38470
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.9017 - loss: 0.4003 - val_accuracy: 0.9052 - val_loss: 0.3872 - learning_rate: 1.0000e-06
# Epoch 107/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8985 - loss: 0.4037
# Epoch 107: val_loss improved from 0.38470 to 0.38115, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8985 - loss: 0.4037 - val_accuracy: 0.9066 - val_loss: 0.3812 - learning_rate: 1.0000e-06
# Epoch 108/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8989 - loss: 0.4053
# Epoch 108: val_loss did not improve from 0.38115
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8990 - loss: 0.4053 - val_accuracy: 0.9047 - val_loss: 0.3881 - learning_rate: 1.0000e-06
# Epoch 109/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8961 - loss: 0.4098
# Epoch 109: val_loss did not improve from 0.38115
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8961 - loss: 0.4098 - val_accuracy: 0.9066 - val_loss: 0.3856 - learning_rate: 1.0000e-06
# Epoch 110/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8985 - loss: 0.4039
# Epoch 110: val_loss did not improve from 0.38115
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8985 - loss: 0.4039 - val_accuracy: 0.9070 - val_loss: 0.3842 - learning_rate: 1.0000e-06
# Epoch 111/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8989 - loss: 0.4023
# Epoch 111: val_loss did not improve from 0.38115
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8989 - loss: 0.4023 - val_accuracy: 0.9058 - val_loss: 0.3812 - learning_rate: 1.0000e-06
# Epoch 112/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9003 - loss: 0.4019
# Epoch 112: val_loss did not improve from 0.38115
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.9003 - loss: 0.4019 - val_accuracy: 0.9073 - val_loss: 0.3830 - learning_rate: 1.0000e-06
# Epoch 113/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8971 - loss: 0.4020
# Epoch 113: val_loss improved from 0.38115 to 0.37877, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8971 - loss: 0.4020 - val_accuracy: 0.9066 - val_loss: 0.3788 - learning_rate: 1.0000e-06
# Epoch 114/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8984 - loss: 0.4078
# Epoch 114: val_loss did not improve from 0.37877
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8984 - loss: 0.4078 - val_accuracy: 0.9053 - val_loss: 0.3872 - learning_rate: 1.0000e-06
# Epoch 115/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9028 - loss: 0.3992
# Epoch 115: val_loss did not improve from 0.37877
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.9028 - loss: 0.3992 - val_accuracy: 0.9057 - val_loss: 0.3845 - learning_rate: 1.0000e-06
# Epoch 116/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8998 - loss: 0.3996
# Epoch 116: val_loss improved from 0.37877 to 0.37815, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8998 - loss: 0.3996 - val_accuracy: 0.9060 - val_loss: 0.3782 - learning_rate: 1.0000e-06
# Epoch 117/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9014 - loss: 0.3972
# Epoch 117: val_loss did not improve from 0.37815
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.9014 - loss: 0.3972 - val_accuracy: 0.9059 - val_loss: 0.3883 - learning_rate: 1.0000e-06
# Epoch 118/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8996 - loss: 0.4023
# Epoch 118: val_loss did not improve from 0.37815
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8996 - loss: 0.4023 - val_accuracy: 0.9046 - val_loss: 0.3856 - learning_rate: 1.0000e-06
# Epoch 119/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8969 - loss: 0.4076
# Epoch 119: val_loss improved from 0.37815 to 0.37585, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8969 - loss: 0.4076 - val_accuracy: 0.9085 - val_loss: 0.3758 - learning_rate: 1.0000e-06
# Epoch 120/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8995 - loss: 0.3990
# Epoch 120: val_loss did not improve from 0.37585
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8995 - loss: 0.3990 - val_accuracy: 0.9031 - val_loss: 0.3873 - learning_rate: 1.0000e-06
# Epoch 121/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8973 - loss: 0.4029
# Epoch 121: val_loss did not improve from 0.37585
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8973 - loss: 0.4029 - val_accuracy: 0.9078 - val_loss: 0.3801 - learning_rate: 1.0000e-06
# Epoch 122/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9021 - loss: 0.3965
# Epoch 122: val_loss did not improve from 0.37585
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.9021 - loss: 0.3965 - val_accuracy: 0.9046 - val_loss: 0.3844 - learning_rate: 1.0000e-06
# Epoch 123/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9005 - loss: 0.3973
# Epoch 123: val_loss did not improve from 0.37585
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.9005 - loss: 0.3973 - val_accuracy: 0.9009 - val_loss: 0.3830 - learning_rate: 1.0000e-06
# Epoch 124/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8993 - loss: 0.4022
# Epoch 124: val_loss did not improve from 0.37585
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8993 - loss: 0.4022 - val_accuracy: 0.9065 - val_loss: 0.3801 - learning_rate: 1.0000e-06
# Epoch 125/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9011 - loss: 0.3991
# Epoch 125: val_loss did not improve from 0.37585
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.9011 - loss: 0.3991 - val_accuracy: 0.9029 - val_loss: 0.3827 - learning_rate: 1.0000e-06
# Epoch 126/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8995 - loss: 0.3984
# Epoch 126: val_loss improved from 0.37585 to 0.37485, saving model to best_model_ferplus_Adam_Flatten.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8995 - loss: 0.3984 - val_accuracy: 0.9074 - val_loss: 0.3749 - learning_rate: 1.0000e-06
# Epoch 127/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8986 - loss: 0.3989
# Epoch 127: val_loss did not improve from 0.37485
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8986 - loss: 0.3989 - val_accuracy: 0.9051 - val_loss: 0.3829 - learning_rate: 1.0000e-06
# Epoch 128/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8999 - loss: 0.3995
# Epoch 128: val_loss did not improve from 0.37485
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8999 - loss: 0.3995 - val_accuracy: 0.9041 - val_loss: 0.3876 - learning_rate: 1.0000e-06
# Epoch 129/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8987 - loss: 0.3990
# Epoch 129: val_loss did not improve from 0.37485
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8987 - loss: 0.3990 - val_accuracy: 0.9070 - val_loss: 0.3780 - learning_rate: 1.0000e-06
# Epoch 130/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8975 - loss: 0.4031
# Epoch 130: val_loss did not improve from 0.37485
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8975 - loss: 0.4031 - val_accuracy: 0.9069 - val_loss: 0.3801 - learning_rate: 1.0000e-06
# Epoch 131/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9014 - loss: 0.3926
# Epoch 131: val_loss did not improve from 0.37485
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.9014 - loss: 0.3926 - val_accuracy: 0.9062 - val_loss: 0.3774 - learning_rate: 1.0000e-06
# Epoch 132/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9029 - loss: 0.3928
# Epoch 132: val_loss did not improve from 0.37485
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.9029 - loss: 0.3928 - val_accuracy: 0.9060 - val_loss: 0.3784 - learning_rate: 1.0000e-06
# Epoch 133/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9011 - loss: 0.3953
# Epoch 133: val_loss did not improve from 0.37485
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.9011 - loss: 0.3953 - val_accuracy: 0.9051 - val_loss: 0.3792 - learning_rate: 1.0000e-06
# Epoch 134/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9015 - loss: 0.3932
# Epoch 134: val_loss did not improve from 0.37485
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.9015 - loss: 0.3932 - val_accuracy: 0.9082 - val_loss: 0.3786 - learning_rate: 1.0000e-06
# Epoch 135/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9017 - loss: 0.3940
# Epoch 135: val_loss did not improve from 0.37485
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.9017 - loss: 0.3940 - val_accuracy: 0.9057 - val_loss: 0.3848 - learning_rate: 1.0000e-06
# Epoch 136/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9001 - loss: 0.3934
# Epoch 136: val_loss did not improve from 0.37485
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.9001 - loss: 0.3934 - val_accuracy: 0.9059 - val_loss: 0.3793 - learning_rate: 1.0000e-06
# Epoch 137/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9021 - loss: 0.3922
# Epoch 137: val_loss did not improve from 0.37485
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.9021 - loss: 0.3922 - val_accuracy: 0.9074 - val_loss: 0.3811 - learning_rate: 1.0000e-06
# Epoch 138/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8989 - loss: 0.3959
# Epoch 138: val_loss did not improve from 0.37485
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8989 - loss: 0.3959 - val_accuracy: 0.9068 - val_loss: 0.3771 - learning_rate: 1.0000e-06
# Epoch 139/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9009 - loss: 0.3916
# Epoch 139: val_loss did not improve from 0.37485
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.9009 - loss: 0.3916 - val_accuracy: 0.9072 - val_loss: 0.3816 - learning_rate: 1.0000e-06
# Epoch 140/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9006 - loss: 0.3982
# Epoch 140: val_loss did not improve from 0.37485
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.9006 - loss: 0.3982 - val_accuracy: 0.9056 - val_loss: 0.3759 - learning_rate: 1.0000e-06
# Epoch 141/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9001 - loss: 0.3988
# Epoch 141: val_loss did not improve from 0.37485
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.9001 - loss: 0.3988 - val_accuracy: 0.9065 - val_loss: 0.3808 - learning_rate: 1.0000e-06
# Epoch 142/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9028 - loss: 0.3927
# Epoch 142: val_loss did not improve from 0.37485
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.9028 - loss: 0.3927 - val_accuracy: 0.9048 - val_loss: 0.3789 - learning_rate: 1.0000e-06
# Epoch 143/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8989 - loss: 0.3975
# Epoch 143: val_loss did not improve from 0.37485
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8989 - loss: 0.3975 - val_accuracy: 0.9066 - val_loss: 0.3749 - learning_rate: 1.0000e-06
# Epoch 144/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8971 - loss: 0.3967
# Epoch 144: val_loss did not improve from 0.37485
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8971 - loss: 0.3967 - val_accuracy: 0.9068 - val_loss: 0.3767 - learning_rate: 1.0000e-06
# Epoch 145/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9013 - loss: 0.3925
# Epoch 145: val_loss did not improve from 0.37485
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.9013 - loss: 0.3925 - val_accuracy: 0.9061 - val_loss: 0.3765 - learning_rate: 1.0000e-06
# Epoch 146/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9013 - loss: 0.3922
# Epoch 146: val_loss did not improve from 0.37485
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.9013 - loss: 0.3922 - val_accuracy: 0.9069 - val_loss: 0.3772 - learning_rate: 1.0000e-06
# Epoch 146: early stopping
# Restoring model weights from the end of the best epoch: 126.

# %% [markdown]
# # 6. 3. Lưu lại model với json và h5

# %%
# Lưu cấu trúc mô hình vào file JSON
fer_json = model.to_json()
with open("ferplus_Adam_Flatten.json", "w") as json_file:
    json_file.write(fer_json)

# Lưu trọng số của mô hình vào file H5
model.save_weights("ferplus_Adam_Flatten.weights.h5")

print("Model structure saved as ferplus_Adam_Flatten.json")
print("Model weights saved as ferplus_Adam_Flatten.weights.h5")
# Out:
# Model structure saved as ferplus_Adam_Flatten.json
# Model weights saved as ferplus_Adam_Flatten.weights.h5

# %% [markdown]
# # **7. Visualizing results**

# %% [markdown]
# # 7. 1. So sánh loss giữa Traning với Validation

# %%
plt.plot(history.history["loss"],'r', label="Training Loss")
plt.plot(history.history["val_loss"],'b', label="Validation Loss")
plt.legend()

# %% [markdown]
# # 7. 2. So sánh accurancy giữa Traning với Validation

# %%
plt.plot(history.history["accuracy"],'r',label="Training Accuracy")
plt.plot(history.history["val_accuracy"],'b',label="Validation Accuracy")
plt.legend()

# %% [markdown]
# # 7. 3. Kiểm tra model với tập Test

# %%
loss = model.evaluate(X_test,y_test)
print("Test Accurancy: " + str(loss[1]))
# Out:
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9210 - loss: 0.3630
# Test Accurancy: 0.9197956323623657

# %%
import numpy as np
import matplotlib.pyplot as plt

# Tạo dự đoán
preds = model.predict(X_test)
y_pred = np.argmax(preds, axis=1)  # Lấy nhãn dự đoán (0-7)
y_true = np.argmax(y_test, axis=1)  # Lấy nhãn thực tế từ one-hot encoding

# Từ điển nhãn
label_dict = {0: "fear", 1: "surprise", 2: "angry", 3: "neutral", 4: "sad", 5: "disgust", 6: "contempt", 7: "happy"}

# Vẽ 24 hình ảnh ngẫu nhiên
figure = plt.figure(figsize=(20, 8))
for i, index in enumerate(np.random.choice(X_test.shape[0], size=24, replace=False)):
    ax = figure.add_subplot(4, 6, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(X_test[index]), cmap='gray')  # Hiển thị ảnh (grayscale)
    
    # Lấy chỉ số và nhãn
    predict_label = label_dict[y_pred[index]]
    true_label = label_dict[y_true[index]]

    # Đặt tiêu đề với màu sắc phù hợp
    color = "green" if y_pred[index] == y_true[index] else "red"
    ax.set_title(f"{predict_label} ({true_label})", color=color)

plt.tight_layout()
plt.show()
# Out:
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step

# %% [markdown]
# # 7. 4. Confusion Matrix

# %%
cm_data = confusion_matrix(np.argmax(y_test, axis = 1 ), y_pred)
cm = pd.DataFrame(cm_data, columns=CLASS_LABELS, index = CLASS_LABELS)
cm.index.name = 'Actual'
cm.columns.name = 'Predicted'
plt.figure(figsize = (15,10))
plt.title('Confusion Matrix', fontsize = 20)
sns.set(font_scale=1.2)
ax = sns.heatmap(cm, cbar=False, cmap="Blues", annot=True, annot_kws={"size": 16}, fmt='g')

# %% [markdown]
# # 7. 5. Classification report

# %%
from sklearn.metrics import classification_report
print(classification_report(np.argmax(y_test, axis = 1 ),y_pred,digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.903     0.985     0.942       959
#            1      0.916     0.877     0.896       934
#            2      0.929     0.912     0.921       966
#            3      0.840     0.847     0.843      1304
#            4      0.878     0.805     0.840       932
#            5      0.954     0.991     0.972       923
#            6      0.972     0.993     0.982       860
#            7      0.923     0.905     0.914       952
#
#     accuracy                          0.911      7830
#    macro avg      0.914     0.914     0.914      7830
# weighted avg      0.910     0.911     0.910      7830

# %% [markdown]
# # **8. Fine tuning**

# %% [markdown]
# # Changing optimizer - Nadam

# %%
model = cnn_model_Flatten()

# %%
from tensorflow.keras.optimizers import Nadam
model.compile(optimizer=tf.keras.optimizers.Nadam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
checkpointer = [
    EarlyStopping(
        monitor='val_loss',  # Sử dụng accuracy để theo dõi
        verbose=1,
        restore_best_weights=True,
        mode="min",
        patience=20  # Tăng patience để cho mô hình thêm thời gian học
    ),
    ModelCheckpoint(
        'best_model_ferplus_Nadam_Flatten.keras',
        monitor="val_loss",  # Sử dụng accuracy để theo dõi
        verbose=1,
        save_best_only=True,
        mode="min"
    ),
    ReduceLROnPlateau(
        monitor='val_loss',  # Sử dụng loss để giảm learning rate
        factor=0.5,
        patience=5,
        min_lr=0.000001,
        verbose=1
    )
]

# %%
history = model.fit(train_generator,
                    epochs=500,
                    batch_size=32,
                    verbose=1,
                    callbacks=[checkpointer],
                    validation_data=val_generator)

# %%
# Lưu cấu trúc mô hình vào file JSON
fer_json = model.to_json()
with open("ferplus_Nadam_Flatten.json", "w") as json_file:
    json_file.write(fer_json)

# Lưu trọng số của mô hình vào file H5
model.save_weights("ferplus_Nadam_Flatten.weights.h5")

print("Model structure saved as ferplus_Nadam_Flatten.json")
print("Model weights saved as ferplus_Nadam_Flatten.weights.h5")

# %%
loss = model.evaluate(X_test,y_test)
print("Test Acc: " + str(loss[1]))

# %%
plt.plot(history.history["loss"],'r', label="Training Loss")
plt.plot(history.history["val_loss"],'b', label="Validation Loss")
plt.legend()

# %%
plt.plot(history.history["accuracy"],'r',label="Training Accuracy")
plt.plot(history.history["val_accuracy"],'b',label="Validation Accuracy")
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Tạo dự đoán
preds = model.predict(X_test)
y_pred = np.argmax(preds, axis=1)  # Lấy nhãn dự đoán (0-6)
y_true = np.argmax(y_test, axis=1)  # Lấy nhãn thực tế từ one-hot encoding

# Từ điển nhãn
label_dict = {0: "fear", 1: "surprise", 2: "angry", 3: "neutral", 4: "sad", 5: "disgust", 6: "contempt", 7: "happy"}
# Vẽ 24 hình ảnh ngẫu nhiên
figure = plt.figure(figsize=(20, 8))
for i, index in enumerate(np.random.choice(X_test.shape[0], size=24, replace=False)):
    ax = figure.add_subplot(4, 6, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(X_test[index]), cmap='gray')  # Hiển thị ảnh (grayscale)
    
    # Lấy chỉ số và nhãn
    predict_label = label_dict[y_pred[index]]
    true_label = label_dict[y_true[index]]

    # Đặt tiêu đề với màu sắc phù hợp
    color = "green" if y_pred[index] == y_true[index] else "red"
    ax.set_title(f"{predict_label} ({true_label})", color=color)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **9. Sử dụng Global Average Pooling thay vì Flatten**

# %%
import tensorflow as tf
from tensorflow.keras.layers import (
    Conv2D, BatchNormalization, MaxPool2D, Dropout, Flatten, Dense, GlobalAveragePooling2D
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers

def cnn_model_GAP():
    model = tf.keras.models.Sequential()

    # Layer 1
    model.add(Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', input_shape=(48, 48, 1)))
    
    # Layer 2
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPool2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))

    # Layer 3
    model.add(Conv2D(128, (5, 5), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPool2D(pool_size=(2, 2)))
    model.add(Dropout(0.3))

    # Layer 4
    model.add(Conv2D(512, (3, 3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(MaxPool2D(pool_size=(2, 2)))
    model.add(Dropout(0.3))

    # Layer 5
    model.add(Conv2D(512, (3, 3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(MaxPool2D(pool_size=(2, 2)))
    model.add(Dropout(0.35))

    # Layer 6
    model.add(Conv2D(512, (3, 3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(MaxPool2D(pool_size=(2, 2)))
    model.add(Dropout(0.4))

    # Global Average Pooling
    model.add(GlobalAveragePooling2D())

    # Fully Connected Layers
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))

    # Output Layer
    model.add(Dense(8, activation='softmax'))

    # Compile Model
    model.compile(
        optimizer=Adam(learning_rate=0.0001),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
model = cnn_model_GAP()

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 48, 48, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 48, 48, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 48, 48, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 24, 24, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 24, 24, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 24, 24, 128)         │         204,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 24, 24, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 12, 12, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 12, 12, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 12, 12, 512)         │         590,336 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 12, 12, 512)         │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 6, 6, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 6, 6, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 6, 6, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 6, 6, 512)           │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 3, 3, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 3, 3, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 3, 3, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 3, 3, 512)           │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 1, 1, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 1, 1, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 512)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 8)                   │           4,104 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,807,624 (22.15 MB)
#  Trainable params: 5,804,168 (22.14 MB)
#  Non-trainable params: 3,456 (13.50 KB)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
# Các callback
checkpointer = [
    EarlyStopping(
        monitor='val_loss',  # Theo dõi loss của tập validation
        verbose=1,
        restore_best_weights=True,
        mode="min",  # Theo dõi loss thấp nhất
        patience=20  # Tăng patience để mô hình có thêm thời gian học
    ),
    ModelCheckpoint(
        'best_model_ferplus_Adam_GAP.keras',
        monitor="val_loss",  # Lưu mô hình tốt nhất dựa trên loss của tập validation
        verbose=1,
        save_best_only=True,
        mode="min"  # Dựa vào loss thấp nhất
    ),
    ReduceLROnPlateau(
        monitor='val_loss',  # Giảm learning rate nếu loss trên tập validation không cải thiện
        factor=0.5,  # Giảm learning rate chậm hơn
        patience=5,  # Giảm learning rate sau 5 epochs nếu không cải thiện
        min_lr=0.000001,
        verbose=1
    )
]

# %%
history = model.fit(train_generator,
                    epochs=500,
                    batch_size=32,
                    verbose=1,
                    callbacks=[checkpointer],
                    validation_data=val_generator)
# Out:
# Epoch 1/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.1432 - loss: 13.3984
# Epoch 1: val_loss improved from inf to 7.99616, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 57s 25ms/step - accuracy: 0.1432 - loss: 13.3973 - val_accuracy: 0.1403 - val_loss: 7.9962 - learning_rate: 1.0000e-04
# Epoch 2/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1787 - loss: 6.4715
# Epoch 2: val_loss improved from 7.99616 to 3.55174, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.1787 - loss: 6.4702 - val_accuracy: 0.2560 - val_loss: 3.5517 - learning_rate: 1.0000e-04
# Epoch 3/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2316 - loss: 3.2264
# Epoch 3: val_loss improved from 3.55174 to 2.47221, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.2316 - loss: 3.2261 - val_accuracy: 0.3483 - val_loss: 2.4722 - learning_rate: 1.0000e-04
# Epoch 4/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3361 - loss: 2.4714
# Epoch 4: val_loss improved from 2.47221 to 2.12923, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.3362 - loss: 2.4712 - val_accuracy: 0.4984 - val_loss: 2.1292 - learning_rate: 1.0000e-04
# Epoch 5/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4483 - loss: 2.2742
# Epoch 5: val_loss improved from 2.12923 to 2.05012, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.4483 - loss: 2.2741 - val_accuracy: 0.5635 - val_loss: 2.0501 - learning_rate: 1.0000e-04
# Epoch 6/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5222 - loss: 2.1732
# Epoch 6: val_loss improved from 2.05012 to 1.96757, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.5222 - loss: 2.1732 - val_accuracy: 0.6209 - val_loss: 1.9676 - learning_rate: 1.0000e-04
# Epoch 7/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5607 - loss: 2.1286
# Epoch 7: val_loss improved from 1.96757 to 1.91767, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.5607 - loss: 2.1286 - val_accuracy: 0.6544 - val_loss: 1.9177 - learning_rate: 1.0000e-04
# Epoch 8/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5964 - loss: 2.0658
# Epoch 8: val_loss improved from 1.91767 to 1.89578, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.5964 - loss: 2.0658 - val_accuracy: 0.6770 - val_loss: 1.8958 - learning_rate: 1.0000e-04
# Epoch 9/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6162 - loss: 2.0509
# Epoch 9: val_loss improved from 1.89578 to 1.88069, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.6162 - loss: 2.0509 - val_accuracy: 0.7016 - val_loss: 1.8807 - learning_rate: 1.0000e-04
# Epoch 10/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6348 - loss: 2.0179
# Epoch 10: val_loss improved from 1.88069 to 1.86562, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.6348 - loss: 2.0179 - val_accuracy: 0.6977 - val_loss: 1.8656 - learning_rate: 1.0000e-04
# Epoch 11/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6510 - loss: 1.9847
# Epoch 11: val_loss improved from 1.86562 to 1.84637, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.6510 - loss: 1.9847 - val_accuracy: 0.7124 - val_loss: 1.8464 - learning_rate: 1.0000e-04
# Epoch 12/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6625 - loss: 1.9664
# Epoch 12: val_loss improved from 1.84637 to 1.83727, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.6625 - loss: 1.9664 - val_accuracy: 0.7123 - val_loss: 1.8373 - learning_rate: 1.0000e-04
# Epoch 13/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6678 - loss: 1.9556
# Epoch 13: val_loss improved from 1.83727 to 1.81488, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.6678 - loss: 1.9556 - val_accuracy: 0.7147 - val_loss: 1.8149 - learning_rate: 1.0000e-04
# Epoch 14/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6703 - loss: 1.9471
# Epoch 14: val_loss improved from 1.81488 to 1.78190, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.6703 - loss: 1.9471 - val_accuracy: 0.7423 - val_loss: 1.7819 - learning_rate: 1.0000e-04
# Epoch 15/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6737 - loss: 1.9374
# Epoch 15: val_loss improved from 1.78190 to 1.76411, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.6738 - loss: 1.9374 - val_accuracy: 0.7455 - val_loss: 1.7641 - learning_rate: 1.0000e-04
# Epoch 16/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6834 - loss: 1.9089
# Epoch 16: val_loss improved from 1.76411 to 1.75162, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.6834 - loss: 1.9089 - val_accuracy: 0.7535 - val_loss: 1.7516 - learning_rate: 1.0000e-04
# Epoch 17/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6903 - loss: 1.8935
# Epoch 17: val_loss improved from 1.75162 to 1.73087, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.6903 - loss: 1.8935 - val_accuracy: 0.7458 - val_loss: 1.7309 - learning_rate: 1.0000e-04
# Epoch 18/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6975 - loss: 1.8615
# Epoch 18: val_loss improved from 1.73087 to 1.71664, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.6975 - loss: 1.8615 - val_accuracy: 0.7549 - val_loss: 1.7166 - learning_rate: 1.0000e-04
# Epoch 19/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6978 - loss: 1.8639
# Epoch 19: val_loss did not improve from 1.71664
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.6978 - loss: 1.8639 - val_accuracy: 0.7563 - val_loss: 1.7168 - learning_rate: 1.0000e-04
# Epoch 20/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7003 - loss: 1.8638
# Epoch 20: val_loss improved from 1.71664 to 1.69967, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7003 - loss: 1.8638 - val_accuracy: 0.7630 - val_loss: 1.6997 - learning_rate: 1.0000e-04
# Epoch 21/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7023 - loss: 1.8326
# Epoch 21: val_loss did not improve from 1.69967
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7023 - loss: 1.8327 - val_accuracy: 0.7480 - val_loss: 1.7113 - learning_rate: 1.0000e-04
# Epoch 22/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7070 - loss: 1.8201
# Epoch 22: val_loss improved from 1.69967 to 1.67297, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7070 - loss: 1.8201 - val_accuracy: 0.7692 - val_loss: 1.6730 - learning_rate: 1.0000e-04
# Epoch 23/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7124 - loss: 1.8129
# Epoch 23: val_loss did not improve from 1.67297
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7124 - loss: 1.8129 - val_accuracy: 0.7516 - val_loss: 1.6770 - learning_rate: 1.0000e-04
# Epoch 24/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7088 - loss: 1.8009
# Epoch 24: val_loss improved from 1.67297 to 1.65787, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7088 - loss: 1.8009 - val_accuracy: 0.7587 - val_loss: 1.6579 - learning_rate: 1.0000e-04
# Epoch 25/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7169 - loss: 1.7954
# Epoch 25: val_loss did not improve from 1.65787
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.7169 - loss: 1.7954 - val_accuracy: 0.7409 - val_loss: 1.6791 - learning_rate: 1.0000e-04
# Epoch 26/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7177 - loss: 1.7713
# Epoch 26: val_loss improved from 1.65787 to 1.63875, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.7177 - loss: 1.7713 - val_accuracy: 0.7605 - val_loss: 1.6387 - learning_rate: 1.0000e-04
# Epoch 27/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7199 - loss: 1.7559
# Epoch 27: val_loss improved from 1.63875 to 1.59130, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.7199 - loss: 1.7559 - val_accuracy: 0.7773 - val_loss: 1.5913 - learning_rate: 1.0000e-04
# Epoch 28/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7193 - loss: 1.7462
# Epoch 28: val_loss improved from 1.59130 to 1.59118, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 18ms/step - accuracy: 0.7193 - loss: 1.7462 - val_accuracy: 0.7753 - val_loss: 1.5912 - learning_rate: 1.0000e-04
# Epoch 29/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7275 - loss: 1.7298
# Epoch 29: val_loss did not improve from 1.59118
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7275 - loss: 1.7298 - val_accuracy: 0.7699 - val_loss: 1.6080 - learning_rate: 1.0000e-04
# Epoch 30/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7218 - loss: 1.7351
# Epoch 30: val_loss did not improve from 1.59118
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7218 - loss: 1.7351 - val_accuracy: 0.7558 - val_loss: 1.6239 - learning_rate: 1.0000e-04
# Epoch 31/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7246 - loss: 1.7351
# Epoch 31: val_loss did not improve from 1.59118
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7246 - loss: 1.7351 - val_accuracy: 0.7689 - val_loss: 1.6012 - learning_rate: 1.0000e-04
# Epoch 32/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7225 - loss: 1.7266
# Epoch 32: val_loss improved from 1.59118 to 1.54746, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7225 - loss: 1.7266 - val_accuracy: 0.7834 - val_loss: 1.5475 - learning_rate: 1.0000e-04
# Epoch 33/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7294 - loss: 1.7088
# Epoch 33: val_loss did not improve from 1.54746
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7294 - loss: 1.7088 - val_accuracy: 0.7817 - val_loss: 1.5630 - learning_rate: 1.0000e-04
# Epoch 34/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7340 - loss: 1.6926
# Epoch 34: val_loss did not improve from 1.54746
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7340 - loss: 1.6926 - val_accuracy: 0.7813 - val_loss: 1.5477 - learning_rate: 1.0000e-04
# Epoch 35/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7396 - loss: 1.6859
# Epoch 35: val_loss did not improve from 1.54746
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7395 - loss: 1.6860 - val_accuracy: 0.7764 - val_loss: 1.5723 - learning_rate: 1.0000e-04
# Epoch 36/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7356 - loss: 1.6877
# Epoch 36: val_loss did not improve from 1.54746
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.7355 - loss: 1.6877 - val_accuracy: 0.7708 - val_loss: 1.5740 - learning_rate: 1.0000e-04
# Epoch 37/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7366 - loss: 1.6775
# Epoch 37: val_loss improved from 1.54746 to 1.54253, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.7366 - loss: 1.6775 - val_accuracy: 0.7792 - val_loss: 1.5425 - learning_rate: 1.0000e-04
# Epoch 38/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7372 - loss: 1.6885
# Epoch 38: val_loss did not improve from 1.54253
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7372 - loss: 1.6886 - val_accuracy: 0.7786 - val_loss: 1.5476 - learning_rate: 1.0000e-04
# Epoch 39/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7366 - loss: 1.6765
# Epoch 39: val_loss did not improve from 1.54253
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 31s 18ms/step - accuracy: 0.7366 - loss: 1.6765 - val_accuracy: 0.7773 - val_loss: 1.5518 - learning_rate: 1.0000e-04
# Epoch 40/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7392 - loss: 1.6689
# Epoch 40: val_loss improved from 1.54253 to 1.52432, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7392 - loss: 1.6689 - val_accuracy: 0.7790 - val_loss: 1.5243 - learning_rate: 1.0000e-04
# Epoch 41/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7387 - loss: 1.6562
# Epoch 41: val_loss improved from 1.52432 to 1.50587, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7387 - loss: 1.6562 - val_accuracy: 0.7877 - val_loss: 1.5059 - learning_rate: 1.0000e-04
# Epoch 42/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7407 - loss: 1.6490
# Epoch 42: val_loss improved from 1.50587 to 1.48922, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7407 - loss: 1.6490 - val_accuracy: 0.7913 - val_loss: 1.4892 - learning_rate: 1.0000e-04
# Epoch 43/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7393 - loss: 1.6360
# Epoch 43: val_loss did not improve from 1.48922
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7393 - loss: 1.6360 - val_accuracy: 0.7832 - val_loss: 1.4969 - learning_rate: 1.0000e-04
# Epoch 44/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7467 - loss: 1.6221
# Epoch 44: val_loss did not improve from 1.48922
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 31s 18ms/step - accuracy: 0.7467 - loss: 1.6221 - val_accuracy: 0.7877 - val_loss: 1.4925 - learning_rate: 1.0000e-04
# Epoch 45/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7417 - loss: 1.6221
# Epoch 45: val_loss improved from 1.48922 to 1.46316, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7417 - loss: 1.6221 - val_accuracy: 0.7993 - val_loss: 1.4632 - learning_rate: 1.0000e-04
# Epoch 46/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7468 - loss: 1.6118
# Epoch 46: val_loss improved from 1.46316 to 1.44628, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7468 - loss: 1.6118 - val_accuracy: 0.8061 - val_loss: 1.4463 - learning_rate: 1.0000e-04
# Epoch 47/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7476 - loss: 1.5937
# Epoch 47: val_loss did not improve from 1.44628
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7476 - loss: 1.5937 - val_accuracy: 0.7986 - val_loss: 1.4567 - learning_rate: 1.0000e-04
# Epoch 48/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7464 - loss: 1.5989
# Epoch 48: val_loss improved from 1.44628 to 1.43412, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7464 - loss: 1.5989 - val_accuracy: 0.8027 - val_loss: 1.4341 - learning_rate: 1.0000e-04
# Epoch 49/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7485 - loss: 1.5867
# Epoch 49: val_loss did not improve from 1.43412
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7485 - loss: 1.5867 - val_accuracy: 0.8010 - val_loss: 1.4433 - learning_rate: 1.0000e-04
# Epoch 50/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7462 - loss: 1.5940
# Epoch 50: val_loss did not improve from 1.43412
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7462 - loss: 1.5940 - val_accuracy: 0.7949 - val_loss: 1.4504 - learning_rate: 1.0000e-04
# Epoch 51/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7488 - loss: 1.5801
# Epoch 51: val_loss did not improve from 1.43412
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 31s 18ms/step - accuracy: 0.7488 - loss: 1.5801 - val_accuracy: 0.7888 - val_loss: 1.4637 - learning_rate: 1.0000e-04
# Epoch 52/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7463 - loss: 1.5820
# Epoch 52: val_loss did not improve from 1.43412
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7463 - loss: 1.5821 - val_accuracy: 0.7954 - val_loss: 1.4350 - learning_rate: 1.0000e-04
# Epoch 53/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7496 - loss: 1.5793
# Epoch 53: val_loss did not improve from 1.43412
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7496 - loss: 1.5793 - val_accuracy: 0.7939 - val_loss: 1.4366 - learning_rate: 1.0000e-04
# Epoch 54/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7623 - loss: 1.4824
# Epoch 54: val_loss improved from 1.43412 to 1.22724, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7623 - loss: 1.4823 - val_accuracy: 0.8171 - val_loss: 1.2272 - learning_rate: 5.0000e-05
# Epoch 55/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7751 - loss: 1.3279
# Epoch 55: val_loss improved from 1.22724 to 1.15154, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7751 - loss: 1.3279 - val_accuracy: 0.8208 - val_loss: 1.1515 - learning_rate: 5.0000e-05
# Epoch 56/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7824 - loss: 1.2573
# Epoch 56: val_loss improved from 1.15154 to 1.11561, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7824 - loss: 1.2573 - val_accuracy: 0.8197 - val_loss: 1.1156 - learning_rate: 5.0000e-05
# Epoch 57/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7837 - loss: 1.2278
# Epoch 57: val_loss improved from 1.11561 to 1.08526, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7837 - loss: 1.2278 - val_accuracy: 0.8220 - val_loss: 1.0853 - learning_rate: 5.0000e-05
# Epoch 58/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7829 - loss: 1.2034
# Epoch 58: val_loss improved from 1.08526 to 1.06105, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7829 - loss: 1.2034 - val_accuracy: 0.8293 - val_loss: 1.0611 - learning_rate: 5.0000e-05
# Epoch 59/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7886 - loss: 1.1793
# Epoch 59: val_loss improved from 1.06105 to 1.05904, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7886 - loss: 1.1793 - val_accuracy: 0.8241 - val_loss: 1.0590 - learning_rate: 5.0000e-05
# Epoch 60/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7847 - loss: 1.1783
# Epoch 60: val_loss improved from 1.05904 to 1.04190, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7847 - loss: 1.1783 - val_accuracy: 0.8273 - val_loss: 1.0419 - learning_rate: 5.0000e-05
# Epoch 61/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7884 - loss: 1.1628
# Epoch 61: val_loss improved from 1.04190 to 1.02431, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7884 - loss: 1.1628 - val_accuracy: 0.8321 - val_loss: 1.0243 - learning_rate: 5.0000e-05
# Epoch 62/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7847 - loss: 1.1682
# Epoch 62: val_loss improved from 1.02431 to 1.02420, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7847 - loss: 1.1682 - val_accuracy: 0.8298 - val_loss: 1.0242 - learning_rate: 5.0000e-05
# Epoch 63/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7852 - loss: 1.1595
# Epoch 63: val_loss did not improve from 1.02420
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 31s 18ms/step - accuracy: 0.7852 - loss: 1.1594 - val_accuracy: 0.8249 - val_loss: 1.0394 - learning_rate: 5.0000e-05
# Epoch 64/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7905 - loss: 1.1419
# Epoch 64: val_loss improved from 1.02420 to 1.00987, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7905 - loss: 1.1419 - val_accuracy: 0.8420 - val_loss: 1.0099 - learning_rate: 5.0000e-05
# Epoch 65/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7913 - loss: 1.1524
# Epoch 65: val_loss did not improve from 1.00987
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7913 - loss: 1.1524 - val_accuracy: 0.8380 - val_loss: 1.0152 - learning_rate: 5.0000e-05
# Epoch 66/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7912 - loss: 1.1374
# Epoch 66: val_loss improved from 1.00987 to 1.00444, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7912 - loss: 1.1374 - val_accuracy: 0.8390 - val_loss: 1.0044 - learning_rate: 5.0000e-05
# Epoch 67/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7892 - loss: 1.1455
# Epoch 67: val_loss did not improve from 1.00444
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7892 - loss: 1.1455 - val_accuracy: 0.8322 - val_loss: 1.0161 - learning_rate: 5.0000e-05
# Epoch 68/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7966 - loss: 1.1226
# Epoch 68: val_loss did not improve from 1.00444
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7966 - loss: 1.1227 - val_accuracy: 0.8363 - val_loss: 1.0087 - learning_rate: 5.0000e-05
# Epoch 69/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7961 - loss: 1.1365
# Epoch 69: val_loss did not improve from 1.00444
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7961 - loss: 1.1365 - val_accuracy: 0.8330 - val_loss: 1.0147 - learning_rate: 5.0000e-05
# Epoch 70/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7935 - loss: 1.1325
# Epoch 70: val_loss did not improve from 1.00444
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7935 - loss: 1.1325 - val_accuracy: 0.8303 - val_loss: 1.0179 - learning_rate: 5.0000e-05
# Epoch 71/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7919 - loss: 1.1369
# Epoch 71: val_loss did not improve from 1.00444
#
# Epoch 71: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.7919 - loss: 1.1369 - val_accuracy: 0.8242 - val_loss: 1.0228 - learning_rate: 5.0000e-05
# Epoch 72/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8059 - loss: 1.0955
# Epoch 72: val_loss improved from 1.00444 to 0.94632, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8060 - loss: 1.0954 - val_accuracy: 0.8379 - val_loss: 0.9463 - learning_rate: 2.5000e-05
# Epoch 73/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8072 - loss: 1.0438
# Epoch 73: val_loss improved from 0.94632 to 0.90044, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8072 - loss: 1.0438 - val_accuracy: 0.8479 - val_loss: 0.9004 - learning_rate: 2.5000e-05
# Epoch 74/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8134 - loss: 0.9890
# Epoch 74: val_loss improved from 0.90044 to 0.87185, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8134 - loss: 0.9890 - val_accuracy: 0.8465 - val_loss: 0.8718 - learning_rate: 2.5000e-05
# Epoch 75/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8145 - loss: 0.9674
# Epoch 75: val_loss improved from 0.87185 to 0.85076, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8145 - loss: 0.9674 - val_accuracy: 0.8479 - val_loss: 0.8508 - learning_rate: 2.5000e-05
# Epoch 76/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8216 - loss: 0.9297
# Epoch 76: val_loss improved from 0.85076 to 0.84170, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8216 - loss: 0.9297 - val_accuracy: 0.8502 - val_loss: 0.8417 - learning_rate: 2.5000e-05
# Epoch 77/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8207 - loss: 0.9258
# Epoch 77: val_loss improved from 0.84170 to 0.82155, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8207 - loss: 0.9258 - val_accuracy: 0.8486 - val_loss: 0.8216 - learning_rate: 2.5000e-05
# Epoch 78/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8229 - loss: 0.9086
# Epoch 78: val_loss improved from 0.82155 to 0.80642, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8229 - loss: 0.9086 - val_accuracy: 0.8543 - val_loss: 0.8064 - learning_rate: 2.5000e-05
# Epoch 79/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8225 - loss: 0.9061
# Epoch 79: val_loss did not improve from 0.80642
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8225 - loss: 0.9061 - val_accuracy: 0.8472 - val_loss: 0.8126 - learning_rate: 2.5000e-05
# Epoch 80/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8250 - loss: 0.8888
# Epoch 80: val_loss improved from 0.80642 to 0.78946, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8250 - loss: 0.8888 - val_accuracy: 0.8545 - val_loss: 0.7895 - learning_rate: 2.5000e-05
# Epoch 81/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8244 - loss: 0.8817
# Epoch 81: val_loss did not improve from 0.78946
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8244 - loss: 0.8817 - val_accuracy: 0.8470 - val_loss: 0.7968 - learning_rate: 2.5000e-05
# Epoch 82/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8222 - loss: 0.8865
# Epoch 82: val_loss did not improve from 0.78946
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8222 - loss: 0.8865 - val_accuracy: 0.8475 - val_loss: 0.7922 - learning_rate: 2.5000e-05
# Epoch 83/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8257 - loss: 0.8688
# Epoch 83: val_loss improved from 0.78946 to 0.77929, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8257 - loss: 0.8688 - val_accuracy: 0.8535 - val_loss: 0.7793 - learning_rate: 2.5000e-05
# Epoch 84/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8236 - loss: 0.8781
# Epoch 84: val_loss improved from 0.77929 to 0.76548, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 18ms/step - accuracy: 0.8236 - loss: 0.8781 - val_accuracy: 0.8598 - val_loss: 0.7655 - learning_rate: 2.5000e-05
# Epoch 85/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8289 - loss: 0.8656
# Epoch 85: val_loss did not improve from 0.76548
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8289 - loss: 0.8656 - val_accuracy: 0.8521 - val_loss: 0.7738 - learning_rate: 2.5000e-05
# Epoch 86/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8250 - loss: 0.8701
# Epoch 86: val_loss did not improve from 0.76548
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8250 - loss: 0.8701 - val_accuracy: 0.8528 - val_loss: 0.7691 - learning_rate: 2.5000e-05
# Epoch 87/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8298 - loss: 0.8578
# Epoch 87: val_loss did not improve from 0.76548
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8298 - loss: 0.8578 - val_accuracy: 0.8452 - val_loss: 0.7839 - learning_rate: 2.5000e-05
# Epoch 88/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8247 - loss: 0.8650
# Epoch 88: val_loss did not improve from 0.76548
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8247 - loss: 0.8650 - val_accuracy: 0.8504 - val_loss: 0.7790 - learning_rate: 2.5000e-05
# Epoch 89/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8316 - loss: 0.8495
# Epoch 89: val_loss improved from 0.76548 to 0.76222, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8316 - loss: 0.8495 - val_accuracy: 0.8554 - val_loss: 0.7622 - learning_rate: 2.5000e-05
# Epoch 90/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8306 - loss: 0.8503
# Epoch 90: val_loss improved from 0.76222 to 0.76075, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8306 - loss: 0.8503 - val_accuracy: 0.8521 - val_loss: 0.7608 - learning_rate: 2.5000e-05
# Epoch 91/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8272 - loss: 0.8559
# Epoch 91: val_loss improved from 0.76075 to 0.76054, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 18ms/step - accuracy: 0.8272 - loss: 0.8559 - val_accuracy: 0.8552 - val_loss: 0.7605 - learning_rate: 2.5000e-05
# Epoch 92/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8266 - loss: 0.8502
# Epoch 92: val_loss improved from 0.76054 to 0.75713, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - accuracy: 0.8266 - loss: 0.8502 - val_accuracy: 0.8560 - val_loss: 0.7571 - learning_rate: 2.5000e-05
# Epoch 93/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8334 - loss: 0.8399
# Epoch 93: val_loss improved from 0.75713 to 0.75071, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - accuracy: 0.8334 - loss: 0.8399 - val_accuracy: 0.8590 - val_loss: 0.7507 - learning_rate: 2.5000e-05
# Epoch 94/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8273 - loss: 0.8493
# Epoch 94: val_loss did not improve from 0.75071
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8273 - loss: 0.8493 - val_accuracy: 0.8551 - val_loss: 0.7527 - learning_rate: 2.5000e-05
# Epoch 95/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8327 - loss: 0.8363
# Epoch 95: val_loss did not improve from 0.75071
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8327 - loss: 0.8363 - val_accuracy: 0.8549 - val_loss: 0.7593 - learning_rate: 2.5000e-05
# Epoch 96/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8303 - loss: 0.8442
# Epoch 96: val_loss improved from 0.75071 to 0.74850, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - accuracy: 0.8303 - loss: 0.8442 - val_accuracy: 0.8593 - val_loss: 0.7485 - learning_rate: 2.5000e-05
# Epoch 97/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8315 - loss: 0.8452
# Epoch 97: val_loss did not improve from 0.74850
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8315 - loss: 0.8452 - val_accuracy: 0.8620 - val_loss: 0.7515 - learning_rate: 2.5000e-05
# Epoch 98/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8359 - loss: 0.8275
# Epoch 98: val_loss did not improve from 0.74850
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8359 - loss: 0.8275 - val_accuracy: 0.8606 - val_loss: 0.7505 - learning_rate: 2.5000e-05
# Epoch 99/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8334 - loss: 0.8369
# Epoch 99: val_loss improved from 0.74850 to 0.73777, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - accuracy: 0.8334 - loss: 0.8369 - val_accuracy: 0.8625 - val_loss: 0.7378 - learning_rate: 2.5000e-05
# Epoch 100/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8346 - loss: 0.8411
# Epoch 100: val_loss did not improve from 0.73777
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8346 - loss: 0.8411 - val_accuracy: 0.8631 - val_loss: 0.7408 - learning_rate: 2.5000e-05
# Epoch 101/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8335 - loss: 0.8388
# Epoch 101: val_loss improved from 0.73777 to 0.73756, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8335 - loss: 0.8388 - val_accuracy: 0.8628 - val_loss: 0.7376 - learning_rate: 2.5000e-05
# Epoch 102/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8313 - loss: 0.8413
# Epoch 102: val_loss did not improve from 0.73756
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8313 - loss: 0.8413 - val_accuracy: 0.8605 - val_loss: 0.7476 - learning_rate: 2.5000e-05
# Epoch 103/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8366 - loss: 0.8310
# Epoch 103: val_loss improved from 0.73756 to 0.73507, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - accuracy: 0.8366 - loss: 0.8311 - val_accuracy: 0.8617 - val_loss: 0.7351 - learning_rate: 2.5000e-05
# Epoch 104/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8386 - loss: 0.8293
# Epoch 104: val_loss did not improve from 0.73507
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 18ms/step - accuracy: 0.8386 - loss: 0.8293 - val_accuracy: 0.8628 - val_loss: 0.7436 - learning_rate: 2.5000e-05
# Epoch 105/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8324 - loss: 0.8436
# Epoch 105: val_loss did not improve from 0.73507
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8324 - loss: 0.8436 - val_accuracy: 0.8593 - val_loss: 0.7465 - learning_rate: 2.5000e-05
# Epoch 106/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8315 - loss: 0.8461
# Epoch 106: val_loss did not improve from 0.73507
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8315 - loss: 0.8461 - val_accuracy: 0.8577 - val_loss: 0.7481 - learning_rate: 2.5000e-05
# Epoch 107/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8312 - loss: 0.8449
# Epoch 107: val_loss did not improve from 0.73507
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8312 - loss: 0.8449 - val_accuracy: 0.8615 - val_loss: 0.7473 - learning_rate: 2.5000e-05
# Epoch 108/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8353 - loss: 0.8337
# Epoch 108: val_loss did not improve from 0.73507
#
# Epoch 108: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8353 - loss: 0.8337 - val_accuracy: 0.8601 - val_loss: 0.7442 - learning_rate: 2.5000e-05
# Epoch 109/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8375 - loss: 0.8249
# Epoch 109: val_loss improved from 0.73507 to 0.72062, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8375 - loss: 0.8248 - val_accuracy: 0.8648 - val_loss: 0.7206 - learning_rate: 1.2500e-05
# Epoch 110/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8476 - loss: 0.7853
# Epoch 110: val_loss improved from 0.72062 to 0.70142, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8476 - loss: 0.7853 - val_accuracy: 0.8629 - val_loss: 0.7014 - learning_rate: 1.2500e-05
# Epoch 111/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8442 - loss: 0.7788
# Epoch 111: val_loss improved from 0.70142 to 0.69167, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8442 - loss: 0.7788 - val_accuracy: 0.8667 - val_loss: 0.6917 - learning_rate: 1.2500e-05
# Epoch 112/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8450 - loss: 0.7668
# Epoch 112: val_loss improved from 0.69167 to 0.68070, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8450 - loss: 0.7668 - val_accuracy: 0.8696 - val_loss: 0.6807 - learning_rate: 1.2500e-05
# Epoch 113/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8506 - loss: 0.7433
# Epoch 113: val_loss improved from 0.68070 to 0.66762, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8506 - loss: 0.7433 - val_accuracy: 0.8718 - val_loss: 0.6676 - learning_rate: 1.2500e-05
# Epoch 114/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8496 - loss: 0.7347
# Epoch 114: val_loss improved from 0.66762 to 0.66668, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8496 - loss: 0.7347 - val_accuracy: 0.8686 - val_loss: 0.6667 - learning_rate: 1.2500e-05
# Epoch 115/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8491 - loss: 0.7345
# Epoch 115: val_loss improved from 0.66668 to 0.66613, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8491 - loss: 0.7345 - val_accuracy: 0.8684 - val_loss: 0.6661 - learning_rate: 1.2500e-05
# Epoch 116/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8505 - loss: 0.7197
# Epoch 116: val_loss improved from 0.66613 to 0.64407, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - accuracy: 0.8505 - loss: 0.7197 - val_accuracy: 0.8726 - val_loss: 0.6441 - learning_rate: 1.2500e-05
# Epoch 117/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8490 - loss: 0.7216
# Epoch 117: val_loss improved from 0.64407 to 0.64361, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - accuracy: 0.8490 - loss: 0.7216 - val_accuracy: 0.8748 - val_loss: 0.6436 - learning_rate: 1.2500e-05
# Epoch 118/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8527 - loss: 0.7097
# Epoch 118: val_loss improved from 0.64361 to 0.64151, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - accuracy: 0.8527 - loss: 0.7097 - val_accuracy: 0.8698 - val_loss: 0.6415 - learning_rate: 1.2500e-05
# Epoch 119/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8528 - loss: 0.7027
# Epoch 119: val_loss improved from 0.64151 to 0.63129, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - accuracy: 0.8528 - loss: 0.7027 - val_accuracy: 0.8719 - val_loss: 0.6313 - learning_rate: 1.2500e-05
# Epoch 120/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8520 - loss: 0.7093
# Epoch 120: val_loss improved from 0.63129 to 0.62735, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - accuracy: 0.8520 - loss: 0.7093 - val_accuracy: 0.8716 - val_loss: 0.6274 - learning_rate: 1.2500e-05
# Epoch 121/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8557 - loss: 0.6923
# Epoch 121: val_loss did not improve from 0.62735
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 18ms/step - accuracy: 0.8557 - loss: 0.6923 - val_accuracy: 0.8694 - val_loss: 0.6302 - learning_rate: 1.2500e-05
# Epoch 122/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8570 - loss: 0.6840
# Epoch 122: val_loss improved from 0.62735 to 0.62056, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8570 - loss: 0.6840 - val_accuracy: 0.8750 - val_loss: 0.6206 - learning_rate: 1.2500e-05
# Epoch 123/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8560 - loss: 0.6868
# Epoch 123: val_loss improved from 0.62056 to 0.61639, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - accuracy: 0.8560 - loss: 0.6868 - val_accuracy: 0.8753 - val_loss: 0.6164 - learning_rate: 1.2500e-05
# Epoch 124/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8551 - loss: 0.6841
# Epoch 124: val_loss did not improve from 0.61639
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8551 - loss: 0.6841 - val_accuracy: 0.8669 - val_loss: 0.6289 - learning_rate: 1.2500e-05
# Epoch 125/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8538 - loss: 0.6790
# Epoch 125: val_loss improved from 0.61639 to 0.61232, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8538 - loss: 0.6790 - val_accuracy: 0.8744 - val_loss: 0.6123 - learning_rate: 1.2500e-05
# Epoch 126/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8576 - loss: 0.6702
# Epoch 126: val_loss did not improve from 0.61232
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8576 - loss: 0.6702 - val_accuracy: 0.8760 - val_loss: 0.6178 - learning_rate: 1.2500e-05
# Epoch 127/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8587 - loss: 0.6715
# Epoch 127: val_loss improved from 0.61232 to 0.60453, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8587 - loss: 0.6715 - val_accuracy: 0.8773 - val_loss: 0.6045 - learning_rate: 1.2500e-05
# Epoch 128/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8569 - loss: 0.6722
# Epoch 128: val_loss did not improve from 0.60453
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8569 - loss: 0.6722 - val_accuracy: 0.8750 - val_loss: 0.6047 - learning_rate: 1.2500e-05
# Epoch 129/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8583 - loss: 0.6714
# Epoch 129: val_loss improved from 0.60453 to 0.59709, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8583 - loss: 0.6714 - val_accuracy: 0.8781 - val_loss: 0.5971 - learning_rate: 1.2500e-05
# Epoch 130/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8601 - loss: 0.6645
# Epoch 130: val_loss improved from 0.59709 to 0.59108, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8601 - loss: 0.6645 - val_accuracy: 0.8796 - val_loss: 0.5911 - learning_rate: 1.2500e-05
# Epoch 131/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8586 - loss: 0.6611
# Epoch 131: val_loss did not improve from 0.59108
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8586 - loss: 0.6611 - val_accuracy: 0.8787 - val_loss: 0.5973 - learning_rate: 1.2500e-05
# Epoch 132/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8590 - loss: 0.6631
# Epoch 132: val_loss did not improve from 0.59108
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8590 - loss: 0.6631 - val_accuracy: 0.8781 - val_loss: 0.5916 - learning_rate: 1.2500e-05
# Epoch 133/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8601 - loss: 0.6637
# Epoch 133: val_loss did not improve from 0.59108
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8601 - loss: 0.6637 - val_accuracy: 0.8799 - val_loss: 0.5920 - learning_rate: 1.2500e-05
# Epoch 134/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8567 - loss: 0.6614
# Epoch 134: val_loss improved from 0.59108 to 0.58627, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8567 - loss: 0.6614 - val_accuracy: 0.8780 - val_loss: 0.5863 - learning_rate: 1.2500e-05
# Epoch 135/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8574 - loss: 0.6589
# Epoch 135: val_loss did not improve from 0.58627
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 18ms/step - accuracy: 0.8575 - loss: 0.6589 - val_accuracy: 0.8767 - val_loss: 0.5951 - learning_rate: 1.2500e-05
# Epoch 136/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8585 - loss: 0.6560
# Epoch 136: val_loss did not improve from 0.58627
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 18ms/step - accuracy: 0.8585 - loss: 0.6560 - val_accuracy: 0.8793 - val_loss: 0.5864 - learning_rate: 1.2500e-05
# Epoch 137/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8613 - loss: 0.6486
# Epoch 137: val_loss did not improve from 0.58627
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8613 - loss: 0.6486 - val_accuracy: 0.8772 - val_loss: 0.5881 - learning_rate: 1.2500e-05
# Epoch 138/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8592 - loss: 0.6536
# Epoch 138: val_loss did not improve from 0.58627
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8592 - loss: 0.6536 - val_accuracy: 0.8765 - val_loss: 0.5890 - learning_rate: 1.2500e-05
# Epoch 139/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8578 - loss: 0.6542
# Epoch 139: val_loss did not improve from 0.58627
#
# Epoch 139: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8578 - loss: 0.6542 - val_accuracy: 0.8785 - val_loss: 0.5894 - learning_rate: 1.2500e-05
# Epoch 140/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8604 - loss: 0.6419
# Epoch 140: val_loss improved from 0.58627 to 0.57956, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8604 - loss: 0.6419 - val_accuracy: 0.8795 - val_loss: 0.5796 - learning_rate: 6.2500e-06
# Epoch 141/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8648 - loss: 0.6321
# Epoch 141: val_loss improved from 0.57956 to 0.57618, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8648 - loss: 0.6321 - val_accuracy: 0.8796 - val_loss: 0.5762 - learning_rate: 6.2500e-06
# Epoch 142/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8684 - loss: 0.6227
# Epoch 142: val_loss improved from 0.57618 to 0.56602, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8684 - loss: 0.6227 - val_accuracy: 0.8799 - val_loss: 0.5660 - learning_rate: 6.2500e-06
# Epoch 143/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8674 - loss: 0.6180
# Epoch 143: val_loss improved from 0.56602 to 0.56519, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8674 - loss: 0.6180 - val_accuracy: 0.8773 - val_loss: 0.5652 - learning_rate: 6.2500e-06
# Epoch 144/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8676 - loss: 0.6167
# Epoch 144: val_loss improved from 0.56519 to 0.55853, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - accuracy: 0.8676 - loss: 0.6167 - val_accuracy: 0.8811 - val_loss: 0.5585 - learning_rate: 6.2500e-06
# Epoch 145/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8686 - loss: 0.6069
# Epoch 145: val_loss improved from 0.55853 to 0.54810, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 18ms/step - accuracy: 0.8686 - loss: 0.6069 - val_accuracy: 0.8842 - val_loss: 0.5481 - learning_rate: 6.2500e-06
# Epoch 146/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8705 - loss: 0.6047
# Epoch 146: val_loss did not improve from 0.54810
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8705 - loss: 0.6047 - val_accuracy: 0.8795 - val_loss: 0.5548 - learning_rate: 6.2500e-06
# Epoch 147/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8704 - loss: 0.6001
# Epoch 147: val_loss improved from 0.54810 to 0.54694, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8704 - loss: 0.6001 - val_accuracy: 0.8820 - val_loss: 0.5469 - learning_rate: 6.2500e-06
# Epoch 148/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8727 - loss: 0.5888
# Epoch 148: val_loss improved from 0.54694 to 0.54456, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8727 - loss: 0.5888 - val_accuracy: 0.8833 - val_loss: 0.5446 - learning_rate: 6.2500e-06
# Epoch 149/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8701 - loss: 0.5921
# Epoch 149: val_loss improved from 0.54456 to 0.53414, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - accuracy: 0.8701 - loss: 0.5921 - val_accuracy: 0.8887 - val_loss: 0.5341 - learning_rate: 6.2500e-06
# Epoch 150/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8717 - loss: 0.5891
# Epoch 150: val_loss did not improve from 0.53414
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8717 - loss: 0.5891 - val_accuracy: 0.8830 - val_loss: 0.5421 - learning_rate: 6.2500e-06
# Epoch 151/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8666 - loss: 0.5957
# Epoch 151: val_loss did not improve from 0.53414
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - accuracy: 0.8666 - loss: 0.5957 - val_accuracy: 0.8783 - val_loss: 0.5395 - learning_rate: 6.2500e-06
# Epoch 152/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8737 - loss: 0.5802
# Epoch 152: val_loss improved from 0.53414 to 0.53162, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - accuracy: 0.8737 - loss: 0.5802 - val_accuracy: 0.8848 - val_loss: 0.5316 - learning_rate: 6.2500e-06
# Epoch 153/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8684 - loss: 0.5854
# Epoch 153: val_loss improved from 0.53162 to 0.52624, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - accuracy: 0.8684 - loss: 0.5854 - val_accuracy: 0.8863 - val_loss: 0.5262 - learning_rate: 6.2500e-06
# Epoch 154/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8735 - loss: 0.5722
# Epoch 154: val_loss did not improve from 0.52624
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - accuracy: 0.8735 - loss: 0.5722 - val_accuracy: 0.8831 - val_loss: 0.5302 - learning_rate: 6.2500e-06
# Epoch 155/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8731 - loss: 0.5706
# Epoch 155: val_loss did not improve from 0.52624
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - accuracy: 0.8731 - loss: 0.5706 - val_accuracy: 0.8856 - val_loss: 0.5270 - learning_rate: 6.2500e-06
# Epoch 156/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8752 - loss: 0.5667
# Epoch 156: val_loss improved from 0.52624 to 0.52298, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8752 - loss: 0.5667 - val_accuracy: 0.8852 - val_loss: 0.5230 - learning_rate: 6.2500e-06
# Epoch 157/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8715 - loss: 0.5776
# Epoch 157: val_loss improved from 0.52298 to 0.51983, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8715 - loss: 0.5776 - val_accuracy: 0.8858 - val_loss: 0.5198 - learning_rate: 6.2500e-06
# Epoch 158/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8779 - loss: 0.5571
# Epoch 158: val_loss improved from 0.51983 to 0.51598, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8779 - loss: 0.5571 - val_accuracy: 0.8894 - val_loss: 0.5160 - learning_rate: 6.2500e-06
# Epoch 159/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8773 - loss: 0.5631
# Epoch 159: val_loss improved from 0.51598 to 0.50994, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8773 - loss: 0.5630 - val_accuracy: 0.8886 - val_loss: 0.5099 - learning_rate: 6.2500e-06
# Epoch 160/500
# 1761/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8756 - loss: 0.5630
# Epoch 160: val_loss did not improve from 0.50994
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8756 - loss: 0.5630 - val_accuracy: 0.8843 - val_loss: 0.5190 - learning_rate: 6.2500e-06
# Epoch 161/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8734 - loss: 0.5591
# Epoch 161: val_loss did not improve from 0.50994
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 33s 18ms/step - accuracy: 0.8734 - loss: 0.5591 - val_accuracy: 0.8838 - val_loss: 0.5167 - learning_rate: 6.2500e-06
# Epoch 162/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8787 - loss: 0.5551
# Epoch 162: val_loss did not improve from 0.50994
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8787 - loss: 0.5551 - val_accuracy: 0.8873 - val_loss: 0.5106 - learning_rate: 6.2500e-06
# Epoch 163/500
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8764 - loss: 0.5539
# Epoch 163: val_loss did not improve from 0.50994
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8764 - loss: 0.5539 - val_accuracy: 0.8860 - val_loss: 0.5121 - learning_rate: 6.2500e-06
# Epoch 164/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8759 - loss: 0.5498
# Epoch 164: val_loss improved from 0.50994 to 0.50652, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8759 - loss: 0.5498 - val_accuracy: 0.8871 - val_loss: 0.5065 - learning_rate: 6.2500e-06
# Epoch 165/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8773 - loss: 0.5486
# Epoch 165: val_loss did not improve from 0.50652
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8773 - loss: 0.5486 - val_accuracy: 0.8872 - val_loss: 0.5122 - learning_rate: 6.2500e-06
# Epoch 166/500
# 1759/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8765 - loss: 0.5461
# Epoch 166: val_loss improved from 0.50652 to 0.50338, saving model to best_model_ferplus_Adam_GAP.keras
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8765 - loss: 0.5461 - val_accuracy: 0.8912 - val_loss: 0.5034 - learning_rate: 6.2500e-06
# Epoch 167/500
# 1760/1762 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8777 - loss: 0.5457
# Epoch 167: val_loss did not improve from 0.50338
# 1762/1762 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8777 - loss: 0.5457 - val_accuracy: 0.8831 - val_loss: 0.5135 - learning_rate: 6.2500e-06
# Epoch 168/500
#  554/1762 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - accuracy: 0.8758 - loss: 0.5443

# %%
# Lưu cấu trúc mô hình vào file JSON
fer_json = model.to_json()
with open("ferplus_Adam_GAP.json", "w") as json_file:
    json_file.write(fer_json)

# Lưu trọng số của mô hình vào file H5
model.save_weights("ferplus_Adam_GAP.weights.h5")

print("Model structure saved as ferplus_Adam_GAP.json")
print("Model weights saved as ferplus_Adam_GAP.weights.h5")

# %%
plt.plot(history.history["loss"],'r', label="Training Loss")
plt.plot(history.history["val_loss"],'b', label="Validation Loss")
plt.legend()

# %%
plt.plot(history.history["accuracy"],'r',label="Training Accuracy")
plt.plot(history.history["val_accuracy"],'b',label="Validation Accuracy")
plt.legend()

# %%
loss = model.evaluate(X_test,y_test)
print("Test Accurancy: " + str(loss[1]))

# %%
import numpy as np
import matplotlib.pyplot as plt

# Tạo dự đoán
preds = model.predict(X_test)
y_pred = np.argmax(preds, axis=1)  # Lấy nhãn dự đoán (0-6)
y_true = np.argmax(y_test, axis=1)  # Lấy nhãn thực tế từ one-hot encoding

# Từ điển nhãn
label_dict = {0: "fear", 1: "surprise", 2: "angry", 3: "neutral", 4: "sad", 5: "disgust", 6: "contempt", 7: "happy"}

# Vẽ 24 hình ảnh ngẫu nhiên
figure = plt.figure(figsize=(20, 8))
for i, index in enumerate(np.random.choice(X_test.shape[0], size=24, replace=False)):
    ax = figure.add_subplot(4, 6, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(X_test[index]), cmap='gray')  # Hiển thị ảnh (grayscale)
    
    # Lấy chỉ số và nhãn
    predict_label = label_dict[y_pred[index]]
    true_label = label_dict[y_true[index]]

    # Đặt tiêu đề với màu sắc phù hợp
    color = "green" if y_pred[index] == y_true[index] else "red"
    ax.set_title(f"{predict_label} ({true_label})", color=color)

plt.tight_layout()
plt.show()

# %%
cm_data = confusion_matrix(np.argmax(y_test, axis = 1 ), y_pred)
cm = pd.DataFrame(cm_data, columns=CLASS_LABELS, index = CLASS_LABELS)
cm.index.name = 'Actual'
cm.columns.name = 'Predicted'
plt.figure(figsize = (15,10))
plt.title('Confusion Matrix', fontsize = 20)
sns.set(font_scale=1.2)
ax = sns.heatmap(cm, cbar=False, cmap="Blues", annot=True, annot_kws={"size": 16}, fmt='g')

# %%
from sklearn.metrics import classification_report
print(classification_report(np.argmax(y_test, axis = 1 ),y_pred,digits=3))

# %% [markdown]
# # **10. Fine Tuning**

# %% [markdown]
# # Change optimizer -  Nadam

# %%
model = cnn_model_GAP()

# %%
from tensorflow.keras.optimizers import Nadam
model.compile(optimizer=tf.keras.optimizers.Nadam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
checkpointer = [
    EarlyStopping(
        monitor='val_loss',  # Sử dụng accuracy để theo dõi
        verbose=1,
        restore_best_weights=True,
        mode="min",
        patience=20  # Tăng patience để cho mô hình thêm thời gian học
    ),
    ModelCheckpoint(
        'best_model_ferplus_Nadam_GAP.keras',
        monitor="val_loss",  # Sử dụng accuracy để theo dõi
        verbose=1,
        save_best_only=True,
        mode="min"
    ),
    ReduceLROnPlateau(
        monitor='val_loss',  # Sử dụng loss để giảm learning rate
        factor=0.5,
        patience=5,
        min_lr=0.000001,
        verbose=1
    )
]

# %%
history = model.fit(train_generator,
                    epochs=500,
                    batch_size=32,
                    verbose=1,
                    callbacks=[checkpointer],
                    validation_data=val_generator)

# %%
# Lưu cấu trúc mô hình vào file JSON
fer_json = model.to_json()
with open("ferplus_Nadam_GAP.json", "w") as json_file:
    json_file.write(fer_json)

# Lưu trọng số của mô hình vào file H5
model.save_weights("ferplus_Nadam_GAP.weights.h5")
print("Model structure saved as ferplus_Nadam_GAP.json")
print("Model weights saved as ferplus_Nadam_GAP.weights.h5")

# %%
loss = model.evaluate(X_test,y_test)
print("Test Acc: " + str(loss[1]))

# %%
plt.plot(history.history["loss"],'r', label="Training Loss")
plt.plot(history.history["val_loss"],'b', label="Validation Loss")
plt.legend()

# %%
plt.plot(history.history["accuracy"],'r',label="Training Accuracy")
plt.plot(history.history["val_accuracy"],'b',label="Validation Accuracy")
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt
# Tạo dự đoán
preds = model.predict(X_test)
y_pred = np.argmax(preds, axis=1)  # Lấy nhãn dự đoán (0-6)
y_true = np.argmax(y_test, axis=1)  # Lấy nhãn thực tế từ one-hot encoding

# Từ điển nhãn
label_dict = {0: "fear", 1: "surprise", 2: "angry", 3: "neutral", 4: "sad", 5: "disgust", 6: "contempt", 7: "happy"}

# Vẽ 24 hình ảnh ngẫu nhiên
figure = plt.figure(figsize=(20, 8))
for i, index in enumerate(np.random.choice(X_test.shape[0], size=24, replace=False)):
    ax = figure.add_subplot(4, 6, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(X_test[index]), cmap='gray')  # Hiển thị ảnh (grayscale)
    
    # Lấy chỉ số và nhãn
    predict_label = label_dict[y_pred[index]]
    true_label = label_dict[y_true[index]]

    # Đặt tiêu đề với màu sắc phù hợp
    color = "green" if y_pred[index] == y_true[index] else "red"
    ax.set_title(f"{predict_label} ({true_label})", color=color)

plt.tight_layout()
plt.show()
